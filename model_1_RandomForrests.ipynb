# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = df[
    ['koi_period', 
     'koi_time0bk', 
     'koi_impact', 
     'koi_duration', 
     'koi_depth',
     'koi_prad',
     'koi_teq',
     'koi_insol',
     'koi_model_snr',
     'koi_steff',
     'koi_slogg',
     'koi_srad',
     'ra',
     'dec',
     'koi_kepmag'
    ]
]

# %%
y = df.koi_disposition.values.reshape(-1,1)
print(y)
# Out:
# [['CONFIRMED']
#  ['FALSE POSITIVE']
#  ['FALSE POSITIVE']
#  ...
#  ['CANDIDATE']
#  ['FALSE POSITIVE']
#  ['FALSE POSITIVE']]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split
X = selected_features.copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train.head()
# Out:
#       koi_period  koi_time0bk  koi_impact  koi_duration  koi_depth  koi_prad  \
# 6122    6.768901   133.077240       0.150       3.61600      123.1      1.24
# 6370    0.733726   132.020050       0.291       2.30900      114.6      0.86
# 2879    7.652707   134.460380       0.970      79.89690      641.1      3.21
# 107     7.953547   174.662240       0.300       2.63120      875.4      2.25
# 29      4.959319   172.258529       0.831       2.22739     9802.0     12.21
#
#       koi_teq  koi_insol  koi_model_snr  koi_steff  koi_slogg  koi_srad  \
# 6122     1017     253.30           10.8       5737      4.327     1.125
# 6370     1867    2891.64           13.8       5855      4.578     0.797
# 2879      989     226.81          254.3       6328      4.481     0.963
# 107       696      55.37           38.4       4768      4.536     0.779
# 29       1103     349.40          696.5       5712      4.359     1.082
#
#              ra        dec  koi_kepmag
# 6122  294.40472  39.351681      14.725
# 6370  284.50391  42.463860      15.770
# 2879  295.50211  38.983540      13.099
# 107   291.15878  40.750271      15.660
# 29    292.16705  48.727589      15.263

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import StandardScaler, MinMaxScaler
X_scaler = MinMaxScaler(X_train)
# y_train_scaler = MinMaxScaler(y_train)

# X_train_scaled =  X_scaler.fit(X_train)
# X_test_scaled = X_scaler.fit(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
# model = LinearRegression()
model = RandomForestClassifier(n_estimators=200)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# # Train the Model

# %%
# print(f"Training Data Score: {model.score(X_train_scaled, y_train)}")
# print(f"Testing Data Score: {model.score(X_test_scaled, y_test)}")

print(f"Training Data Score: {model.score(X_train, y_train)}")
print(f"Testing Data Score: {model.score(X_test, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.7517162471395881

# %%
# scores = []
# This was for my own enjoyment
for i in range(100,2000,100):
    model = RandomForestClassifier(n_estimators=i)
    model.fit(X_train, y_train)
    print(f'Number of estimators: {i}')
    print(f"Training Data Score: {model.score(X_train, y_train)}")
#     model.score(X_train, y_train)
    print(f"Testing Data Score: {model.score(X_test, y_test)}")
    print('\n------------')
#     score = model.score(X_test, y_test)
# Out:
# Number of estimators: 100
# Training Data Score: 1.0
# Testing Data Score: 0.7562929061784897
#
# ------------
# Number of estimators: 200
# Training Data Score: 1.0
# Testing Data Score: 0.7528604118993135
#
# ------------
# Number of estimators: 300
# Training Data Score: 1.0
# Testing Data Score: 0.7517162471395881
#
# ------------
# Number of estimators: 400
# Training Data Score: 1.0
# Testing Data Score: 0.7545766590389016
#
# ------------
# Number of estimators: 500
# Training Data Score: 1.0
# Testing Data Score: 0.7528604118993135
#
# ------------
# Number of estimators: 600
# Training Data Score: 1.0
# Testing Data Score: 0.7545766590389016
#
# ------------
# Number of estimators: 700
# Training Data Score: 1.0
# Testing Data Score: 0.7528604118993135
#
# ------------
# Number of estimators: 800
# Training Data Score: 1.0
# Testing Data Score: 0.7534324942791762
#
# ------------
# Number of estimators: 900
# Training Data Score: 1.0
# Testing Data Score: 0.7551487414187643
#
# ------------
# Number of estimators: 1000
# Training Data Score: 1.0
# Testing Data Score: 0.7545766590389016
#
# ------------
# Number of estimators: 1100
# Training Data Score: 1.0
# Testing Data Score: 0.7574370709382151
#
# ------------
# Number of estimators: 1200
# Training Data Score: 1.0
# Testing Data Score: 0.7528604118993135
#
# ------------
# Number of estimators: 1300
# Training Data Score: 1.0
# Testing Data Score: 0.7477116704805492
#
# ------------
# Number of estimators: 1400
# Training Data Score: 1.0
# Testing Data Score: 0.7574370709382151
#
# ------------
# Number of estimators: 1500
# Training Data Score: 1.0
# Testing Data Score: 0.7522883295194508
#
# ------------
# Number of estimators: 1600
# Training Data Score: 1.0
# Testing Data Score: 0.7505720823798627
#
# ------------
# Number of estimators: 1700
# Training Data Score: 1.0
# Testing Data Score: 0.7568649885583524
#
# ------------
# Number of estimators: 1800
# Training Data Score: 1.0
# Testing Data Score: 0.7545766590389016
#
# ------------
# Number of estimators: 1900
# Training Data Score: 1.0
# Testing Data Score: 0.7482837528604119
#
# ------------

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
import numpy as np
param_grid = {'n_estimators': np.arange(100,1000,10),
              'max_features': ['auto', 'sqrt', 'log2']}
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 270 candidates, totalling 1350 fits
# [CV] max_features=auto, n_estimators=100 .............................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] . max_features=auto, n_estimators=100, score=0.779, total=   2.7s
# [CV] max_features=auto, n_estimators=100 .............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.6s remaining:    0.0s
# [CV] . max_features=auto, n_estimators=100, score=0.762, total=   2.0s
# [CV] max_features=auto, n_estimators=100 .............................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.7s remaining:    0.0s
# [CV] . max_features=auto, n_estimators=100, score=0.746, total=   2.5s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] . max_features=auto, n_estimators=100, score=0.757, total=   2.2s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] . max_features=auto, n_estimators=100, score=0.764, total=   2.5s
# [CV] max_features=auto, n_estimators=110 .............................
# [CV] . max_features=auto, n_estimators=110, score=0.774, total=   2.2s
# [CV] max_features=auto, n_estimators=110 .............................
# [CV] . max_features=auto, n_estimators=110, score=0.760, total=   2.7s
# [CV] max_features=auto, n_estimators=110 .............................
# [CV] . max_features=auto, n_estimators=110, score=0.746, total=   2.2s
# [CV] max_features=auto, n_estimators=110 .............................
# [CV] . max_features=auto, n_estimators=110, score=0.749, total=   2.6s
# [CV] max_features=auto, n_estimators=110 .............................
# [CV] . max_features=auto, n_estimators=110, score=0.762, total=   2.1s
# [CV] max_features=auto, n_estimators=120 .............................
# [CV] . max_features=auto, n_estimators=120, score=0.774, total=   2.8s
# [CV] max_features=auto, n_estimators=120 .............................
# [CV] . max_features=auto, n_estimators=120, score=0.756, total=   2.7s
# [CV] max_features=auto, n_estimators=120 .............................
# [CV] . max_features=auto, n_estimators=120, score=0.745, total=   2.7s
# [CV] max_features=auto, n_estimators=120 .............................
# [CV] . max_features=auto, n_estimators=120, score=0.745, total=   2.3s
# [CV] max_features=auto, n_estimators=120 .............................
# [CV] . max_features=auto, n_estimators=120, score=0.766, total=   2.7s
# [CV] max_features=auto, n_estimators=130 .............................
# [CV] . max_features=auto, n_estimators=130, score=0.768, total=   2.5s
# [CV] max_features=auto, n_estimators=130 .............................
# [CV] . max_features=auto, n_estimators=130, score=0.777, total=   3.0s
# [CV] max_features=auto, n_estimators=130 .............................
# [CV] . max_features=auto, n_estimators=130, score=0.749, total=   2.7s
# [CV] max_features=auto, n_estimators=130 .............................
# [CV] . max_features=auto, n_estimators=130, score=0.756, total=   3.0s
# [CV] max_features=auto, n_estimators=130 .............................
# [CV] . max_features=auto, n_estimators=130, score=0.766, total=   3.3s
# [CV] max_features=auto, n_estimators=140 .............................
# [CV] . max_features=auto, n_estimators=140, score=0.774, total=   2.9s
# [CV] max_features=auto, n_estimators=140 .............................
# [CV] . max_features=auto, n_estimators=140, score=0.760, total=   3.5s
# [CV] max_features=auto, n_estimators=140 .............................
# [CV] . max_features=auto, n_estimators=140, score=0.746, total=   3.5s
# [CV] max_features=auto, n_estimators=140 .............................
# [CV] . max_features=auto, n_estimators=140, score=0.744, total=   3.1s
# [CV] max_features=auto, n_estimators=140 .............................
# [CV] . max_features=auto, n_estimators=140, score=0.758, total=   3.2s
# [CV] max_features=auto, n_estimators=150 .............................
# [CV] . max_features=auto, n_estimators=150, score=0.767, total=   3.5s
# [CV] max_features=auto, n_estimators=150 .............................
# [CV] . max_features=auto, n_estimators=150, score=0.774, total=   3.1s
# [CV] max_features=auto, n_estimators=150 .............................
# [CV] . max_features=auto, n_estimators=150, score=0.756, total=   3.3s
# [CV] max_features=auto, n_estimators=150 .............................
# [CV] . max_features=auto, n_estimators=150, score=0.761, total=   3.4s
# [CV] max_features=auto, n_estimators=150 .............................
# [CV] . max_features=auto, n_estimators=150, score=0.763, total=   2.9s
# [CV] max_features=auto, n_estimators=160 .............................
# [CV] . max_features=auto, n_estimators=160, score=0.776, total=   4.2s
# [CV] max_features=auto, n_estimators=160 .............................
# [CV] . max_features=auto, n_estimators=160, score=0.774, total=   3.6s
# [CV] max_features=auto, n_estimators=160 .............................
# [CV] . max_features=auto, n_estimators=160, score=0.745, total=   3.5s
# [CV] max_features=auto, n_estimators=160 .............................
# [CV] . max_features=auto, n_estimators=160, score=0.754, total=   3.2s
# [CV] max_features=auto, n_estimators=160 .............................
# [CV] . max_features=auto, n_estimators=160, score=0.767, total=   3.6s
# [CV] max_features=auto, n_estimators=170 .............................
# [CV] . max_features=auto, n_estimators=170, score=0.773, total=   3.7s
# [CV] max_features=auto, n_estimators=170 .............................
# [CV] . max_features=auto, n_estimators=170, score=0.758, total=   3.3s
# [CV] max_features=auto, n_estimators=170 .............................
# [CV] . max_features=auto, n_estimators=170, score=0.735, total=   3.8s
# [CV] max_features=auto, n_estimators=170 .............................
# [CV] . max_features=auto, n_estimators=170, score=0.757, total=   3.9s
# [CV] max_features=auto, n_estimators=170 .............................
# [CV] . max_features=auto, n_estimators=170, score=0.762, total=   3.9s
# [CV] max_features=auto, n_estimators=180 .............................
# [CV] . max_features=auto, n_estimators=180, score=0.779, total=   3.6s
# [CV] max_features=auto, n_estimators=180 .............................
# [CV] . max_features=auto, n_estimators=180, score=0.769, total=   4.0s
# [CV] max_features=auto, n_estimators=180 .............................
# [CV] . max_features=auto, n_estimators=180, score=0.751, total=   4.0s
# [CV] max_features=auto, n_estimators=180 .............................
# [CV] . max_features=auto, n_estimators=180, score=0.755, total=   3.9s
# [CV] max_features=auto, n_estimators=180 .............................
# [CV] . max_features=auto, n_estimators=180, score=0.772, total=   5.0s
# [CV] max_features=auto, n_estimators=190 .............................
# [CV] . max_features=auto, n_estimators=190, score=0.769, total=   4.2s
# [CV] max_features=auto, n_estimators=190 .............................
# [CV] . max_features=auto, n_estimators=190, score=0.765, total=   4.1s
# [CV] max_features=auto, n_estimators=190 .............................
# [CV] . max_features=auto, n_estimators=190, score=0.746, total=   3.9s
# [CV] max_features=auto, n_estimators=190 .............................
# [CV] . max_features=auto, n_estimators=190, score=0.753, total=   4.1s
# [CV] max_features=auto, n_estimators=190 .............................
# [CV] . max_features=auto, n_estimators=190, score=0.763, total=   4.2s
# [CV] max_features=auto, n_estimators=200 .............................
# [CV] . max_features=auto, n_estimators=200, score=0.775, total=   4.3s
# [CV] max_features=auto, n_estimators=200 .............................
# [CV] . max_features=auto, n_estimators=200, score=0.759, total=   4.3s
# [CV] max_features=auto, n_estimators=200 .............................
# [CV] . max_features=auto, n_estimators=200, score=0.745, total=   4.4s
# [CV] max_features=auto, n_estimators=200 .............................
# [CV] . max_features=auto, n_estimators=200, score=0.756, total=   3.9s
# [CV] max_features=auto, n_estimators=200 .............................
# [CV] . max_features=auto, n_estimators=200, score=0.764, total=   4.5s
# [CV] max_features=auto, n_estimators=210 .............................
# [CV] . max_features=auto, n_estimators=210, score=0.777, total=   4.5s
# [CV] max_features=auto, n_estimators=210 .............................
# [CV] . max_features=auto, n_estimators=210, score=0.763, total=   4.5s
# [CV] max_features=auto, n_estimators=210 .............................
# [CV] . max_features=auto, n_estimators=210, score=0.745, total=   4.7s
# [CV] max_features=auto, n_estimators=210 .............................
# [CV] . max_features=auto, n_estimators=210, score=0.759, total=   4.6s
# [CV] max_features=auto, n_estimators=210 .............................
# [CV] . max_features=auto, n_estimators=210, score=0.763, total=   4.5s
# [CV] max_features=auto, n_estimators=220 .............................
# [CV] . max_features=auto, n_estimators=220, score=0.775, total=   4.7s
# [CV] max_features=auto, n_estimators=220 .............................
# [CV] . max_features=auto, n_estimators=220, score=0.761, total=   4.7s
# [CV] max_features=auto, n_estimators=220 .............................
# [CV] . max_features=auto, n_estimators=220, score=0.747, total=   4.7s
# [CV] max_features=auto, n_estimators=220 .............................
# [CV] . max_features=auto, n_estimators=220, score=0.758, total=   4.7s
# [CV] max_features=auto, n_estimators=220 .............................
# [CV] . max_features=auto, n_estimators=220, score=0.768, total=   4.7s
# [CV] max_features=auto, n_estimators=230 .............................
# [CV] . max_features=auto, n_estimators=230, score=0.773, total=   4.9s
# [CV] max_features=auto, n_estimators=230 .............................
# [CV] . max_features=auto, n_estimators=230, score=0.767, total=   5.0s
# [CV] max_features=auto, n_estimators=230 .............................
# [CV] . max_features=auto, n_estimators=230, score=0.749, total=   5.0s
# [CV] max_features=auto, n_estimators=230 .............................
# [CV] . max_features=auto, n_estimators=230, score=0.759, total=   4.9s
# [CV] max_features=auto, n_estimators=230 .............................
# [CV] . max_features=auto, n_estimators=230, score=0.763, total=   4.9s
# [CV] max_features=auto, n_estimators=240 .............................
# [CV] . max_features=auto, n_estimators=240, score=0.775, total=   5.5s
# [CV] max_features=auto, n_estimators=240 .............................
# [CV] . max_features=auto, n_estimators=240, score=0.765, total=   5.2s
# [CV] max_features=auto, n_estimators=240 .............................
# [CV] . max_features=auto, n_estimators=240, score=0.749, total=   5.1s
# [CV] max_features=auto, n_estimators=240 .............................
# [CV] . max_features=auto, n_estimators=240, score=0.762, total=   5.0s
# [CV] max_features=auto, n_estimators=240 .............................
# [CV] . max_features=auto, n_estimators=240, score=0.766, total=   5.0s
# [CV] max_features=auto, n_estimators=250 .............................
# [CV] . max_features=auto, n_estimators=250, score=0.774, total=   5.9s
# [CV] max_features=auto, n_estimators=250 .............................
# [CV] . max_features=auto, n_estimators=250, score=0.771, total=   6.4s
# [CV] max_features=auto, n_estimators=250 .............................
# [CV] . max_features=auto, n_estimators=250, score=0.747, total=   8.5s
# [CV] max_features=auto, n_estimators=250 .............................
# [CV] . max_features=auto, n_estimators=250, score=0.754, total=   7.5s
# [CV] max_features=auto, n_estimators=250 .............................
# [CV] . max_features=auto, n_estimators=250, score=0.768, total=   5.3s
# [CV] max_features=auto, n_estimators=260 .............................
# [CV] . max_features=auto, n_estimators=260, score=0.772, total=   5.5s
# [CV] max_features=auto, n_estimators=260 .............................
# [CV] . max_features=auto, n_estimators=260, score=0.762, total=   5.7s
# [CV] max_features=auto, n_estimators=260 .............................
# [CV] . max_features=auto, n_estimators=260, score=0.748, total=   6.4s
# [CV] max_features=auto, n_estimators=260 .............................
# [CV] . max_features=auto, n_estimators=260, score=0.755, total=   5.5s
# [CV] max_features=auto, n_estimators=260 .............................
# [CV] . max_features=auto, n_estimators=260, score=0.762, total=   6.0s
# [CV] max_features=auto, n_estimators=270 .............................
# [CV] . max_features=auto, n_estimators=270, score=0.765, total=   5.7s
# [CV] max_features=auto, n_estimators=270 .............................
# [CV] . max_features=auto, n_estimators=270, score=0.768, total=   5.8s
# [CV] max_features=auto, n_estimators=270 .............................
# [CV] . max_features=auto, n_estimators=270, score=0.748, total=   5.7s
# [CV] max_features=auto, n_estimators=270 .............................
# [CV] . max_features=auto, n_estimators=270, score=0.758, total=   5.7s
# [CV] max_features=auto, n_estimators=270 .............................
# [CV] . max_features=auto, n_estimators=270, score=0.757, total=   5.8s
# [CV] max_features=auto, n_estimators=280 .............................
# [CV] . max_features=auto, n_estimators=280, score=0.772, total=   6.2s
# [CV] max_features=auto, n_estimators=280 .............................
# [CV] . max_features=auto, n_estimators=280, score=0.768, total=   6.0s
# [CV] max_features=auto, n_estimators=280 .............................
# [CV] . max_features=auto, n_estimators=280, score=0.741, total=   6.1s
# [CV] max_features=auto, n_estimators=280 .............................
# [CV] . max_features=auto, n_estimators=280, score=0.755, total=   6.2s
# [CV] max_features=auto, n_estimators=280 .............................
# [CV] . max_features=auto, n_estimators=280, score=0.763, total=   6.3s
# [CV] max_features=auto, n_estimators=290 .............................
# [CV] . max_features=auto, n_estimators=290, score=0.768, total=   6.2s
# [CV] max_features=auto, n_estimators=290 .............................
# [CV] . max_features=auto, n_estimators=290, score=0.772, total=   6.1s
# [CV] max_features=auto, n_estimators=290 .............................
# [CV] . max_features=auto, n_estimators=290, score=0.747, total=   6.2s
# [CV] max_features=auto, n_estimators=290 .............................
# [CV] . max_features=auto, n_estimators=290, score=0.757, total=   6.4s
# [CV] max_features=auto, n_estimators=290 .............................
# [CV] . max_features=auto, n_estimators=290, score=0.762, total=   6.1s
# [CV] max_features=auto, n_estimators=300 .............................
# [CV] . max_features=auto, n_estimators=300, score=0.774, total=   6.3s
# [CV] max_features=auto, n_estimators=300 .............................
# [CV] . max_features=auto, n_estimators=300, score=0.761, total=   6.8s
# [CV] max_features=auto, n_estimators=300 .............................
# [CV] . max_features=auto, n_estimators=300, score=0.744, total=   6.7s
# [CV] max_features=auto, n_estimators=300 .............................
# [CV] . max_features=auto, n_estimators=300, score=0.751, total=   6.5s
# [CV] max_features=auto, n_estimators=300 .............................
# [CV] . max_features=auto, n_estimators=300, score=0.770, total=   6.7s
# [CV] max_features=auto, n_estimators=310 .............................
# [CV] . max_features=auto, n_estimators=310, score=0.769, total=   6.7s
# [CV] max_features=auto, n_estimators=310 .............................
# [CV] . max_features=auto, n_estimators=310, score=0.766, total=   6.6s
# [CV] max_features=auto, n_estimators=310 .............................
# [CV] . max_features=auto, n_estimators=310, score=0.740, total=   6.9s
# [CV] max_features=auto, n_estimators=310 .............................
# [CV] . max_features=auto, n_estimators=310, score=0.754, total=   6.5s
# [CV] max_features=auto, n_estimators=310 .............................
# [CV] . max_features=auto, n_estimators=310, score=0.762, total=   6.4s
# [CV] max_features=auto, n_estimators=320 .............................
# [CV] . max_features=auto, n_estimators=320, score=0.771, total=   7.0s
# [CV] max_features=auto, n_estimators=320 .............................
# [CV] . max_features=auto, n_estimators=320, score=0.763, total=   6.6s
# [CV] max_features=auto, n_estimators=320 .............................
# [CV] . max_features=auto, n_estimators=320, score=0.752, total=   7.2s
# [CV] max_features=auto, n_estimators=320 .............................
# [CV] . max_features=auto, n_estimators=320, score=0.758, total=   6.9s
# [CV] max_features=auto, n_estimators=320 .............................
# [CV] . max_features=auto, n_estimators=320, score=0.765, total=   6.7s
# [CV] max_features=auto, n_estimators=330 .............................
# [CV] . max_features=auto, n_estimators=330, score=0.776, total=   7.6s
# [CV] max_features=auto, n_estimators=330 .............................
# [CV] . max_features=auto, n_estimators=330, score=0.768, total=   7.0s
# [CV] max_features=auto, n_estimators=330 .............................
# [CV] . max_features=auto, n_estimators=330, score=0.749, total=   7.3s
# [CV] max_features=auto, n_estimators=330 .............................
# [CV] . max_features=auto, n_estimators=330, score=0.754, total=   6.8s
# [CV] max_features=auto, n_estimators=330 .............................
# [CV] . max_features=auto, n_estimators=330, score=0.769, total=   7.3s
# [CV] max_features=auto, n_estimators=340 .............................
# [CV] . max_features=auto, n_estimators=340, score=0.774, total=   7.0s
# [CV] max_features=auto, n_estimators=340 .............................
# [CV] . max_features=auto, n_estimators=340, score=0.764, total=   7.5s
# [CV] max_features=auto, n_estimators=340 .............................
# [CV] . max_features=auto, n_estimators=340, score=0.751, total=   7.1s
# [CV] max_features=auto, n_estimators=340 .............................
# [CV] . max_features=auto, n_estimators=340, score=0.755, total=   7.8s
# [CV] max_features=auto, n_estimators=340 .............................
# [CV] . max_features=auto, n_estimators=340, score=0.768, total=   7.4s
# [CV] max_features=auto, n_estimators=350 .............................
# [CV] . max_features=auto, n_estimators=350, score=0.778, total=   7.7s
# [CV] max_features=auto, n_estimators=350 .............................
# [CV] . max_features=auto, n_estimators=350, score=0.765, total=   7.7s
# [CV] max_features=auto, n_estimators=350 .............................
# [CV] . max_features=auto, n_estimators=350, score=0.745, total=   7.9s
# [CV] max_features=auto, n_estimators=350 .............................
# [CV] . max_features=auto, n_estimators=350, score=0.753, total=   7.3s
# [CV] max_features=auto, n_estimators=350 .............................
# [CV] . max_features=auto, n_estimators=350, score=0.761, total=   7.7s
# [CV] max_features=auto, n_estimators=360 .............................
# [CV] . max_features=auto, n_estimators=360, score=0.776, total=   7.6s
# [CV] max_features=auto, n_estimators=360 .............................
# [CV] . max_features=auto, n_estimators=360, score=0.771, total=   8.0s
# [CV] max_features=auto, n_estimators=360 .............................
# [CV] . max_features=auto, n_estimators=360, score=0.749, total=   8.1s
# [CV] max_features=auto, n_estimators=360 .............................
# [CV] . max_features=auto, n_estimators=360, score=0.753, total=   7.5s
# [CV] max_features=auto, n_estimators=360 .............................
# [CV] . max_features=auto, n_estimators=360, score=0.758, total=   8.3s
# [CV] max_features=auto, n_estimators=370 .............................
# [CV] . max_features=auto, n_estimators=370, score=0.776, total=   7.7s
# [CV] max_features=auto, n_estimators=370 .............................
# [CV] . max_features=auto, n_estimators=370, score=0.759, total=   8.1s
# [CV] max_features=auto, n_estimators=370 .............................
# [CV] . max_features=auto, n_estimators=370, score=0.749, total=   8.1s
# [CV] max_features=auto, n_estimators=370 .............................
# [CV] . max_features=auto, n_estimators=370, score=0.752, total=   7.7s
# [CV] max_features=auto, n_estimators=370 .............................
# [CV] . max_features=auto, n_estimators=370, score=0.763, total=  10.7s
# [CV] max_features=auto, n_estimators=380 .............................
# [CV] . max_features=auto, n_estimators=380, score=0.777, total=   8.8s
# [CV] max_features=auto, n_estimators=380 .............................
# [CV] . max_features=auto, n_estimators=380, score=0.771, total=   8.4s
# [CV] max_features=auto, n_estimators=380 .............................
# [CV] . max_features=auto, n_estimators=380, score=0.750, total=   7.8s
# [CV] max_features=auto, n_estimators=380 .............................
# [CV] . max_features=auto, n_estimators=380, score=0.756, total=   8.2s
# [CV] max_features=auto, n_estimators=380 .............................
# [CV] . max_features=auto, n_estimators=380, score=0.762, total=   8.4s
# [CV] max_features=auto, n_estimators=390 .............................
# [CV] . max_features=auto, n_estimators=390, score=0.776, total=   8.2s
# [CV] max_features=auto, n_estimators=390 .............................
# [CV] . max_features=auto, n_estimators=390, score=0.765, total=   8.9s
# [CV] max_features=auto, n_estimators=390 .............................
# [CV] . max_features=auto, n_estimators=390, score=0.747, total=   8.6s
# [CV] max_features=auto, n_estimators=390 .............................
# [CV] . max_features=auto, n_estimators=390, score=0.745, total=   9.0s
# [CV] max_features=auto, n_estimators=390 .............................
# [CV] . max_features=auto, n_estimators=390, score=0.763, total=   8.8s
# [CV] max_features=auto, n_estimators=400 .............................
# [CV] . max_features=auto, n_estimators=400, score=0.770, total=   8.2s
# [CV] max_features=auto, n_estimators=400 .............................
# [CV] . max_features=auto, n_estimators=400, score=0.772, total=   8.6s
# [CV] max_features=auto, n_estimators=400 .............................
# [CV] . max_features=auto, n_estimators=400, score=0.750, total=   8.7s
# [CV] max_features=auto, n_estimators=400 .............................
# [CV] . max_features=auto, n_estimators=400, score=0.757, total=   8.3s
# [CV] max_features=auto, n_estimators=400 .............................
# [CV] . max_features=auto, n_estimators=400, score=0.765, total=   8.6s
# [CV] max_features=auto, n_estimators=410 .............................
# [CV] . max_features=auto, n_estimators=410, score=0.770, total=   8.9s
# [CV] max_features=auto, n_estimators=410 .............................
# [CV] . max_features=auto, n_estimators=410, score=0.764, total=   8.8s
# [CV] max_features=auto, n_estimators=410 .............................
# [CV] . max_features=auto, n_estimators=410, score=0.744, total=  10.6s
# [CV] max_features=auto, n_estimators=410 .............................
# [CV] . max_features=auto, n_estimators=410, score=0.757, total=  11.9s
# [CV] max_features=auto, n_estimators=410 .............................
# [CV] . max_features=auto, n_estimators=410, score=0.761, total=  10.9s
# [CV] max_features=auto, n_estimators=420 .............................
# [CV] . max_features=auto, n_estimators=420, score=0.779, total=   8.5s
# [CV] max_features=auto, n_estimators=420 .............................
# [CV] . max_features=auto, n_estimators=420, score=0.763, total=   9.5s
# [CV] max_features=auto, n_estimators=420 .............................
# [CV] . max_features=auto, n_estimators=420, score=0.747, total=   9.0s
# [CV] max_features=auto, n_estimators=420 .............................
# [CV] . max_features=auto, n_estimators=420, score=0.755, total=   9.2s
# [CV] max_features=auto, n_estimators=420 .............................
# [CV] . max_features=auto, n_estimators=420, score=0.762, total=   9.1s
# [CV] max_features=auto, n_estimators=430 .............................
# [CV] . max_features=auto, n_estimators=430, score=0.769, total=   9.3s
# [CV] max_features=auto, n_estimators=430 .............................
# [CV] . max_features=auto, n_estimators=430, score=0.761, total=   8.8s
# [CV] max_features=auto, n_estimators=430 .............................
# [CV] . max_features=auto, n_estimators=430, score=0.750, total=   9.4s
# [CV] max_features=auto, n_estimators=430 .............................
# [CV] . max_features=auto, n_estimators=430, score=0.760, total=   9.1s
# [CV] max_features=auto, n_estimators=430 .............................
# [CV] . max_features=auto, n_estimators=430, score=0.760, total=   9.3s
# [CV] max_features=auto, n_estimators=440 .............................
# [CV] . max_features=auto, n_estimators=440, score=0.773, total=   9.8s
# [CV] max_features=auto, n_estimators=440 .............................
# [CV] . max_features=auto, n_estimators=440, score=0.765, total=   9.6s
# [CV] max_features=auto, n_estimators=440 .............................
# [CV] . max_features=auto, n_estimators=440, score=0.751, total=   9.3s
# [CV] max_features=auto, n_estimators=440 .............................
# [CV] . max_features=auto, n_estimators=440, score=0.757, total=   9.3s
# [CV] max_features=auto, n_estimators=440 .............................
# [CV] . max_features=auto, n_estimators=440, score=0.761, total=   9.4s
# [CV] max_features=auto, n_estimators=450 .............................
# [CV] . max_features=auto, n_estimators=450, score=0.775, total=   9.5s
# [CV] max_features=auto, n_estimators=450 .............................
# [CV] . max_features=auto, n_estimators=450, score=0.769, total=   9.5s
# [CV] max_features=auto, n_estimators=450 .............................
# [CV] . max_features=auto, n_estimators=450, score=0.747, total=   9.4s
# [CV] max_features=auto, n_estimators=450 .............................
# [CV] . max_features=auto, n_estimators=450, score=0.750, total=   9.3s
# [CV] max_features=auto, n_estimators=450 .............................
# [CV] . max_features=auto, n_estimators=450, score=0.765, total=   9.5s
# [CV] max_features=auto, n_estimators=460 .............................
# [CV] . max_features=auto, n_estimators=460, score=0.771, total=   9.8s
# [CV] max_features=auto, n_estimators=460 .............................
# [CV] . max_features=auto, n_estimators=460, score=0.771, total=   9.8s
# [CV] max_features=auto, n_estimators=460 .............................
# [CV] . max_features=auto, n_estimators=460, score=0.753, total=   9.6s
# [CV] max_features=auto, n_estimators=460 .............................
# [CV] . max_features=auto, n_estimators=460, score=0.756, total=  10.0s
# [CV] max_features=auto, n_estimators=460 .............................
# [CV] . max_features=auto, n_estimators=460, score=0.763, total=  10.2s
# [CV] max_features=auto, n_estimators=470 .............................
# [CV] . max_features=auto, n_estimators=470, score=0.773, total=  10.1s
# [CV] max_features=auto, n_estimators=470 .............................
# [CV] . max_features=auto, n_estimators=470, score=0.765, total=  10.1s
# [CV] max_features=auto, n_estimators=470 .............................
# [CV] . max_features=auto, n_estimators=470, score=0.753, total=  10.7s
# [CV] max_features=auto, n_estimators=470 .............................
# [CV] . max_features=auto, n_estimators=470, score=0.757, total=  12.0s
# [CV] max_features=auto, n_estimators=470 .............................
# [CV] . max_features=auto, n_estimators=470, score=0.765, total=  10.3s
# [CV] max_features=auto, n_estimators=480 .............................
# [CV] . max_features=auto, n_estimators=480, score=0.778, total=  10.4s
# [CV] max_features=auto, n_estimators=480 .............................
# [CV] . max_features=auto, n_estimators=480, score=0.770, total=  10.4s
# [CV] max_features=auto, n_estimators=480 .............................
# [CV] . max_features=auto, n_estimators=480, score=0.746, total=  10.1s
# [CV] max_features=auto, n_estimators=480 .............................
# [CV] . max_features=auto, n_estimators=480, score=0.758, total=  10.0s
# [CV] max_features=auto, n_estimators=480 .............................
# [CV] . max_features=auto, n_estimators=480, score=0.759, total=  10.7s
# [CV] max_features=auto, n_estimators=490 .............................
# [CV] . max_features=auto, n_estimators=490, score=0.773, total=  10.5s
# [CV] max_features=auto, n_estimators=490 .............................
# [CV] . max_features=auto, n_estimators=490, score=0.765, total=  10.4s
# [CV] max_features=auto, n_estimators=490 .............................
# [CV] . max_features=auto, n_estimators=490, score=0.748, total=  11.2s
# [CV] max_features=auto, n_estimators=490 .............................
# [CV] . max_features=auto, n_estimators=490, score=0.758, total=  10.3s
# [CV] max_features=auto, n_estimators=490 .............................
# [CV] . max_features=auto, n_estimators=490, score=0.762, total=  10.4s
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] . max_features=auto, n_estimators=500, score=0.775, total=  10.7s
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] . max_features=auto, n_estimators=500, score=0.765, total=  11.0s
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] . max_features=auto, n_estimators=500, score=0.745, total=  10.5s
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] . max_features=auto, n_estimators=500, score=0.760, total=  10.4s
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] . max_features=auto, n_estimators=500, score=0.760, total=  10.5s
# [CV] max_features=auto, n_estimators=510 .............................
# [CV] . max_features=auto, n_estimators=510, score=0.774, total=  10.8s
# [CV] max_features=auto, n_estimators=510 .............................
# [CV] . max_features=auto, n_estimators=510, score=0.764, total=  10.8s
# [CV] max_features=auto, n_estimators=510 .............................
# [CV] . max_features=auto, n_estimators=510, score=0.747, total=  11.0s
# [CV] max_features=auto, n_estimators=510 .............................
# [CV] . max_features=auto, n_estimators=510, score=0.760, total=  10.6s
# [CV] max_features=auto, n_estimators=510 .............................
# [CV] . max_features=auto, n_estimators=510, score=0.758, total=  11.0s
# [CV] max_features=auto, n_estimators=520 .............................
# [CV] . max_features=auto, n_estimators=520, score=0.775, total=  10.9s
# [CV] max_features=auto, n_estimators=520 .............................
# [CV] . max_features=auto, n_estimators=520, score=0.767, total=  10.9s
# [CV] max_features=auto, n_estimators=520 .............................
# [CV] . max_features=auto, n_estimators=520, score=0.745, total=  11.1s
# [CV] max_features=auto, n_estimators=520 .............................
# [CV] . max_features=auto, n_estimators=520, score=0.755, total=  10.9s
# [CV] max_features=auto, n_estimators=520 .............................
# [CV] . max_features=auto, n_estimators=520, score=0.760, total=  10.9s
# [CV] max_features=auto, n_estimators=530 .............................
# [CV] . max_features=auto, n_estimators=530, score=0.776, total=  13.2s
# [CV] max_features=auto, n_estimators=530 .............................
# [CV] . max_features=auto, n_estimators=530, score=0.771, total=  16.1s
# [CV] max_features=auto, n_estimators=530 .............................
# [CV] . max_features=auto, n_estimators=530, score=0.752, total=  11.4s
# [CV] max_features=auto, n_estimators=530 .............................
# [CV] . max_features=auto, n_estimators=530, score=0.754, total=  11.7s
# [CV] max_features=auto, n_estimators=530 .............................
# [CV] . max_features=auto, n_estimators=530, score=0.766, total=  11.5s
# [CV] max_features=auto, n_estimators=540 .............................
# [CV] . max_features=auto, n_estimators=540, score=0.775, total=  13.6s
# [CV] max_features=auto, n_estimators=540 .............................
# [CV] . max_features=auto, n_estimators=540, score=0.773, total=  11.5s
# [CV] max_features=auto, n_estimators=540 .............................
# [CV] . max_features=auto, n_estimators=540, score=0.748, total=  11.4s
# [CV] max_features=auto, n_estimators=540 .............................
# [CV] . max_features=auto, n_estimators=540, score=0.760, total=  11.6s
# [CV] max_features=auto, n_estimators=540 .............................
# [CV] . max_features=auto, n_estimators=540, score=0.762, total=  11.5s
# [CV] max_features=auto, n_estimators=550 .............................
# [CV] . max_features=auto, n_estimators=550, score=0.769, total=  12.0s
# [CV] max_features=auto, n_estimators=550 .............................
# [CV] . max_features=auto, n_estimators=550, score=0.764, total=  11.8s
# [CV] max_features=auto, n_estimators=550 .............................
# [CV] . max_features=auto, n_estimators=550, score=0.749, total=  11.4s
# [CV] max_features=auto, n_estimators=550 .............................
# [CV] . max_features=auto, n_estimators=550, score=0.748, total=  12.0s
# [CV] max_features=auto, n_estimators=550 .............................
# [CV] . max_features=auto, n_estimators=550, score=0.760, total=  11.5s
# [CV] max_features=auto, n_estimators=560 .............................
# [CV] . max_features=auto, n_estimators=560, score=0.777, total=  11.8s
# [CV] max_features=auto, n_estimators=560 .............................
# [CV] . max_features=auto, n_estimators=560, score=0.766, total=  12.3s
# [CV] max_features=auto, n_estimators=560 .............................
# [CV] . max_features=auto, n_estimators=560, score=0.745, total=  11.7s
# [CV] max_features=auto, n_estimators=560 .............................
# [CV] . max_features=auto, n_estimators=560, score=0.759, total=  12.2s
# [CV] max_features=auto, n_estimators=560 .............................
# [CV] . max_features=auto, n_estimators=560, score=0.762, total=  11.7s
# [CV] max_features=auto, n_estimators=570 .............................
# [CV] . max_features=auto, n_estimators=570, score=0.778, total=  12.4s
# [CV] max_features=auto, n_estimators=570 .............................
# [CV] . max_features=auto, n_estimators=570, score=0.764, total=  12.1s
# [CV] max_features=auto, n_estimators=570 .............................
# [CV] . max_features=auto, n_estimators=570, score=0.749, total=  12.3s
# [CV] max_features=auto, n_estimators=570 .............................
# [CV] . max_features=auto, n_estimators=570, score=0.758, total=  12.2s
# [CV] max_features=auto, n_estimators=570 .............................
# [CV] . max_features=auto, n_estimators=570, score=0.760, total=  12.4s
# [CV] max_features=auto, n_estimators=580 .............................
# [CV] . max_features=auto, n_estimators=580, score=0.771, total=  12.1s
# [CV] max_features=auto, n_estimators=580 .............................
# [CV] . max_features=auto, n_estimators=580, score=0.764, total=  13.0s
# [CV] max_features=auto, n_estimators=580 .............................
# [CV] . max_features=auto, n_estimators=580, score=0.746, total=  12.0s
# [CV] max_features=auto, n_estimators=580 .............................
# [CV] . max_features=auto, n_estimators=580, score=0.751, total=  12.6s
# [CV] max_features=auto, n_estimators=580 .............................
# [CV] . max_features=auto, n_estimators=580, score=0.760, total=  12.0s
# [CV] max_features=auto, n_estimators=590 .............................
# [CV] . max_features=auto, n_estimators=590, score=0.778, total=  12.8s
# [CV] max_features=auto, n_estimators=590 .............................
# [CV] . max_features=auto, n_estimators=590, score=0.767, total=  12.4s
# [CV] max_features=auto, n_estimators=590 .............................
# [CV] . max_features=auto, n_estimators=590, score=0.746, total=  13.0s
# [CV] max_features=auto, n_estimators=590 .............................
# [CV] . max_features=auto, n_estimators=590, score=0.750, total=  12.2s
# [CV] max_features=auto, n_estimators=590 .............................
# [CV] . max_features=auto, n_estimators=590, score=0.768, total=  12.8s
# [CV] max_features=auto, n_estimators=600 .............................
# [CV] . max_features=auto, n_estimators=600, score=0.772, total=  12.5s
# [CV] max_features=auto, n_estimators=600 .............................
# [CV] . max_features=auto, n_estimators=600, score=0.767, total=  12.9s
# [CV] max_features=auto, n_estimators=600 .............................
# [CV] . max_features=auto, n_estimators=600, score=0.749, total=  13.2s
# [CV] max_features=auto, n_estimators=600 .............................
# [CV] . max_features=auto, n_estimators=600, score=0.760, total=  12.3s
# [CV] max_features=auto, n_estimators=600 .............................
# [CV] . max_features=auto, n_estimators=600, score=0.766, total=  13.1s
# [CV] max_features=auto, n_estimators=610 .............................
# [CV] . max_features=auto, n_estimators=610, score=0.771, total=  12.8s
# [CV] max_features=auto, n_estimators=610 .............................
# [CV] . max_features=auto, n_estimators=610, score=0.771, total=  13.7s
# [CV] max_features=auto, n_estimators=610 .............................
# [CV] . max_features=auto, n_estimators=610, score=0.745, total=  13.4s
# [CV] max_features=auto, n_estimators=610 .............................
# [CV] . max_features=auto, n_estimators=610, score=0.756, total=  12.5s
# [CV] max_features=auto, n_estimators=610 .............................
# [CV] . max_features=auto, n_estimators=610, score=0.765, total=  12.9s
# [CV] max_features=auto, n_estimators=620 .............................
# [CV] . max_features=auto, n_estimators=620, score=0.776, total=  13.5s
# [CV] max_features=auto, n_estimators=620 .............................
# [CV] . max_features=auto, n_estimators=620, score=0.761, total=  13.3s
# [CV] max_features=auto, n_estimators=620 .............................
# [CV] . max_features=auto, n_estimators=620, score=0.745, total=  13.0s
# [CV] max_features=auto, n_estimators=620 .............................
# [CV] . max_features=auto, n_estimators=620, score=0.754, total=  18.3s
# [CV] max_features=auto, n_estimators=620 .............................
# [CV] . max_features=auto, n_estimators=620, score=0.761, total=  15.3s
# [CV] max_features=auto, n_estimators=630 .............................
# [CV] . max_features=auto, n_estimators=630, score=0.782, total=  14.0s
# [CV] max_features=auto, n_estimators=630 .............................
# [CV] . max_features=auto, n_estimators=630, score=0.764, total=  13.7s
# [CV] max_features=auto, n_estimators=630 .............................
# [CV] . max_features=auto, n_estimators=630, score=0.748, total=  13.1s
# [CV] max_features=auto, n_estimators=630 .............................
# [CV] . max_features=auto, n_estimators=630, score=0.748, total=  13.4s
# [CV] max_features=auto, n_estimators=630 .............................
# [CV] . max_features=auto, n_estimators=630, score=0.760, total=  13.7s
# [CV] max_features=auto, n_estimators=640 .............................
# [CV] . max_features=auto, n_estimators=640, score=0.773, total=  13.8s
# [CV] max_features=auto, n_estimators=640 .............................
# [CV] . max_features=auto, n_estimators=640, score=0.773, total=  13.3s
# [CV] max_features=auto, n_estimators=640 .............................
# [CV] . max_features=auto, n_estimators=640, score=0.748, total=  14.2s
# [CV] max_features=auto, n_estimators=640 .............................
# [CV] . max_features=auto, n_estimators=640, score=0.751, total=  13.8s
# [CV] max_features=auto, n_estimators=640 .............................
# [CV] . max_features=auto, n_estimators=640, score=0.763, total=  13.8s
# [CV] max_features=auto, n_estimators=650 .............................
# [CV] . max_features=auto, n_estimators=650, score=0.771, total=  13.9s
# [CV] max_features=auto, n_estimators=650 .............................
# [CV] . max_features=auto, n_estimators=650, score=0.763, total=  13.7s
# [CV] max_features=auto, n_estimators=650 .............................
# [CV] . max_features=auto, n_estimators=650, score=0.745, total=  13.8s
# [CV] max_features=auto, n_estimators=650 .............................
# [CV] . max_features=auto, n_estimators=650, score=0.755, total=  13.7s
# [CV] max_features=auto, n_estimators=650 .............................
# [CV] . max_features=auto, n_estimators=650, score=0.761, total=  13.9s
# [CV] max_features=auto, n_estimators=660 .............................
# [CV] . max_features=auto, n_estimators=660, score=0.773, total=  14.5s
# [CV] max_features=auto, n_estimators=660 .............................
# [CV] . max_features=auto, n_estimators=660, score=0.767, total=  13.7s
# [CV] max_features=auto, n_estimators=660 .............................
# [CV] . max_features=auto, n_estimators=660, score=0.749, total=  13.6s
# [CV] max_features=auto, n_estimators=660 .............................
# [CV] . max_features=auto, n_estimators=660, score=0.758, total=  14.0s
# [CV] max_features=auto, n_estimators=660 .............................
# [CV] . max_features=auto, n_estimators=660, score=0.763, total=  13.9s
# [CV] max_features=auto, n_estimators=670 .............................
# [CV] . max_features=auto, n_estimators=670, score=0.773, total=  14.6s
# [CV] max_features=auto, n_estimators=670 .............................
# [CV] . max_features=auto, n_estimators=670, score=0.769, total=  16.3s
# [CV] max_features=auto, n_estimators=670 .............................
# [CV] . max_features=auto, n_estimators=670, score=0.746, total=  14.6s
# [CV] max_features=auto, n_estimators=670 .............................
# [CV] . max_features=auto, n_estimators=670, score=0.750, total=  14.5s
# [CV] max_features=auto, n_estimators=670 .............................
# [CV] . max_features=auto, n_estimators=670, score=0.763, total=  14.6s
# [CV] max_features=auto, n_estimators=680 .............................
# [CV] . max_features=auto, n_estimators=680, score=0.774, total=  15.8s
# [CV] max_features=auto, n_estimators=680 .............................
# [CV] . max_features=auto, n_estimators=680, score=0.765, total=  14.5s
# [CV] max_features=auto, n_estimators=680 .............................
# [CV] . max_features=auto, n_estimators=680, score=0.741, total=  14.6s
# [CV] max_features=auto, n_estimators=680 .............................
# [CV] . max_features=auto, n_estimators=680, score=0.760, total=  14.9s
# [CV] max_features=auto, n_estimators=680 .............................
# [CV] . max_features=auto, n_estimators=680, score=0.767, total=  19.1s
# [CV] max_features=auto, n_estimators=690 .............................
# [CV] . max_features=auto, n_estimators=690, score=0.772, total=  15.1s
# [CV] max_features=auto, n_estimators=690 .............................
# [CV] . max_features=auto, n_estimators=690, score=0.762, total=  15.1s
# [CV] max_features=auto, n_estimators=690 .............................
# [CV] . max_features=auto, n_estimators=690, score=0.746, total=  15.5s
# [CV] max_features=auto, n_estimators=690 .............................
# [CV] . max_features=auto, n_estimators=690, score=0.757, total=  17.9s
# [CV] max_features=auto, n_estimators=690 .............................
# [CV] . max_features=auto, n_estimators=690, score=0.765, total=  14.7s
# [CV] max_features=auto, n_estimators=700 .............................
# [CV] . max_features=auto, n_estimators=700, score=0.771, total=  15.3s
# [CV] max_features=auto, n_estimators=700 .............................
# [CV] . max_features=auto, n_estimators=700, score=0.765, total=  14.9s
# [CV] max_features=auto, n_estimators=700 .............................
# [CV] . max_features=auto, n_estimators=700, score=0.745, total=  14.8s
# [CV] max_features=auto, n_estimators=700 .............................
# [CV] . max_features=auto, n_estimators=700, score=0.753, total=  19.0s
# [CV] max_features=auto, n_estimators=700 .............................
# [CV] . max_features=auto, n_estimators=700, score=0.762, total=  18.9s
# [CV] max_features=auto, n_estimators=710 .............................
# [CV] . max_features=auto, n_estimators=710, score=0.776, total=  15.3s
# [CV] max_features=auto, n_estimators=710 .............................
# [CV] . max_features=auto, n_estimators=710, score=0.771, total=  15.3s
# [CV] max_features=auto, n_estimators=710 .............................
# [CV] . max_features=auto, n_estimators=710, score=0.746, total=  16.4s
# [CV] max_features=auto, n_estimators=710 .............................
# [CV] . max_features=auto, n_estimators=710, score=0.746, total=  15.2s
# [CV] max_features=auto, n_estimators=710 .............................
# [CV] . max_features=auto, n_estimators=710, score=0.766, total=  16.2s
# [CV] max_features=auto, n_estimators=720 .............................
# [CV] . max_features=auto, n_estimators=720, score=0.770, total=  15.4s
# [CV] max_features=auto, n_estimators=720 .............................
# [CV] . max_features=auto, n_estimators=720, score=0.765, total=  15.8s
# [CV] max_features=auto, n_estimators=720 .............................
# [CV] . max_features=auto, n_estimators=720, score=0.751, total=  15.1s
# [CV] max_features=auto, n_estimators=720 .............................
# [CV] . max_features=auto, n_estimators=720, score=0.759, total=  15.1s
# [CV] max_features=auto, n_estimators=720 .............................
# [CV] . max_features=auto, n_estimators=720, score=0.762, total=  15.5s
# [CV] max_features=auto, n_estimators=730 .............................
# [CV] . max_features=auto, n_estimators=730, score=0.775, total=  15.7s
# [CV] max_features=auto, n_estimators=730 .............................
# [CV] . max_features=auto, n_estimators=730, score=0.773, total=  15.7s
# [CV] max_features=auto, n_estimators=730 .............................
# [CV] . max_features=auto, n_estimators=730, score=0.745, total=  15.7s
# [CV] max_features=auto, n_estimators=730 .............................
# [CV] . max_features=auto, n_estimators=730, score=0.756, total=  15.3s
# [CV] max_features=auto, n_estimators=730 .............................
# [CV] . max_features=auto, n_estimators=730, score=0.764, total=  15.7s
# [CV] max_features=auto, n_estimators=740 .............................
# [CV] . max_features=auto, n_estimators=740, score=0.774, total=  15.7s
# [CV] max_features=auto, n_estimators=740 .............................
# [CV] . max_features=auto, n_estimators=740, score=0.768, total=  15.7s
# [CV] max_features=auto, n_estimators=740 .............................
# [CV] . max_features=auto, n_estimators=740, score=0.745, total=  16.0s
# [CV] max_features=auto, n_estimators=740 .............................
# [CV] . max_features=auto, n_estimators=740, score=0.752, total=  15.7s
# [CV] max_features=auto, n_estimators=740 .............................
# [CV] . max_features=auto, n_estimators=740, score=0.763, total=  15.9s
# [CV] max_features=auto, n_estimators=750 .............................
# [CV] . max_features=auto, n_estimators=750, score=0.772, total=  15.9s
# [CV] max_features=auto, n_estimators=750 .............................
# [CV] . max_features=auto, n_estimators=750, score=0.767, total=  16.7s
# [CV] max_features=auto, n_estimators=750 .............................
# [CV] . max_features=auto, n_estimators=750, score=0.743, total=  15.9s
# [CV] max_features=auto, n_estimators=750 .............................
# [CV] . max_features=auto, n_estimators=750, score=0.752, total=  16.1s
# [CV] max_features=auto, n_estimators=750 .............................
# [CV] . max_features=auto, n_estimators=750, score=0.763, total=  15.8s
# [CV] max_features=auto, n_estimators=760 .............................
# [CV] . max_features=auto, n_estimators=760, score=0.776, total=  16.6s
# [CV] max_features=auto, n_estimators=760 .............................
# [CV] . max_features=auto, n_estimators=760, score=0.771, total=  16.1s
# [CV] max_features=auto, n_estimators=760 .............................
# [CV] . max_features=auto, n_estimators=760, score=0.748, total=  16.3s
# [CV] max_features=auto, n_estimators=760 .............................
# [CV] . max_features=auto, n_estimators=760, score=0.755, total=  16.7s
# [CV] max_features=auto, n_estimators=760 .............................
# [CV] . max_features=auto, n_estimators=760, score=0.762, total=  16.2s
# [CV] max_features=auto, n_estimators=770 .............................
# ...
# [CV] max_features=log2, n_estimators=790 .............................
# [CV] . max_features=log2, n_estimators=790, score=0.755, total=  17.0s
# [CV] max_features=log2, n_estimators=790 .............................
# [CV] . max_features=log2, n_estimators=790, score=0.759, total=  16.9s
# [CV] max_features=log2, n_estimators=800 .............................
# [CV] . max_features=log2, n_estimators=800, score=0.778, total=  24.5s
# [CV] max_features=log2, n_estimators=800 .............................
# [CV] . max_features=log2, n_estimators=800, score=0.765, total=  18.0s
# [CV] max_features=log2, n_estimators=800 .............................
# [CV] . max_features=log2, n_estimators=800, score=0.745, total=  17.0s
# [CV] max_features=log2, n_estimators=800 .............................
# [CV] . max_features=log2, n_estimators=800, score=0.757, total=  17.8s
# [CV] max_features=log2, n_estimators=800 .............................
# [CV] . max_features=log2, n_estimators=800, score=0.762, total=  17.0s
# [CV] max_features=log2, n_estimators=810 .............................
# [CV] . max_features=log2, n_estimators=810, score=0.776, total=  18.0s
# [CV] max_features=log2, n_estimators=810 .............................
# [CV] . max_features=log2, n_estimators=810, score=0.767, total=  17.8s
# [CV] max_features=log2, n_estimators=810 .............................
# [CV] . max_features=log2, n_estimators=810, score=0.745, total=  17.7s
# [CV] max_features=log2, n_estimators=810 .............................
# [CV] . max_features=log2, n_estimators=810, score=0.754, total=  18.0s
# [CV] max_features=log2, n_estimators=810 .............................
# [CV] . max_features=log2, n_estimators=810, score=0.760, total=  17.0s
# [CV] max_features=log2, n_estimators=820 .............................
# [CV] . max_features=log2, n_estimators=820, score=0.776, total=  17.7s
# [CV] max_features=log2, n_estimators=820 .............................
# [CV] . max_features=log2, n_estimators=820, score=0.765, total=  18.1s
# [CV] max_features=log2, n_estimators=820 .............................
# [CV] . max_features=log2, n_estimators=820, score=0.746, total=  17.9s
# [CV] max_features=log2, n_estimators=820 .............................
# [CV] . max_features=log2, n_estimators=820, score=0.757, total=  18.3s
# [CV] max_features=log2, n_estimators=820 .............................
# [CV] . max_features=log2, n_estimators=820, score=0.761, total=  17.4s
# [CV] max_features=log2, n_estimators=830 .............................
# [CV] . max_features=log2, n_estimators=830, score=0.771, total=  17.7s
# [CV] max_features=log2, n_estimators=830 .............................
# [CV] . max_features=log2, n_estimators=830, score=0.765, total=  17.9s
# [CV] max_features=log2, n_estimators=830 .............................
# [CV] . max_features=log2, n_estimators=830, score=0.748, total=  17.7s
# [CV] max_features=log2, n_estimators=830 .............................
# [CV] . max_features=log2, n_estimators=830, score=0.758, total=  17.9s
# [CV] max_features=log2, n_estimators=830 .............................
# [CV] . max_features=log2, n_estimators=830, score=0.764, total=  17.9s
# [CV] max_features=log2, n_estimators=840 .............................
# [CV] . max_features=log2, n_estimators=840, score=0.776, total=  18.1s
# [CV] max_features=log2, n_estimators=840 .............................
# [CV] . max_features=log2, n_estimators=840, score=0.763, total=  18.6s
# [CV] max_features=log2, n_estimators=840 .............................
# [CV] . max_features=log2, n_estimators=840, score=0.745, total=  18.4s
# [CV] max_features=log2, n_estimators=840 .............................
# [CV] . max_features=log2, n_estimators=840, score=0.754, total=  18.0s
# [CV] max_features=log2, n_estimators=840 .............................
# [CV] . max_features=log2, n_estimators=840, score=0.765, total=  19.0s
# [CV] max_features=log2, n_estimators=850 .............................
# [CV] . max_features=log2, n_estimators=850, score=0.778, total=  18.4s
# [CV] max_features=log2, n_estimators=850 .............................
# [CV] . max_features=log2, n_estimators=850, score=0.763, total=  18.5s
# [CV] max_features=log2, n_estimators=850 .............................
# [CV] . max_features=log2, n_estimators=850, score=0.747, total=  18.1s
# [CV] max_features=log2, n_estimators=850 .............................
# [CV] . max_features=log2, n_estimators=850, score=0.759, total=  18.4s
# [CV] max_features=log2, n_estimators=850 .............................
# [CV] . max_features=log2, n_estimators=850, score=0.762, total=  22.2s
# [CV] max_features=log2, n_estimators=860 .............................
# [CV] . max_features=log2, n_estimators=860, score=0.776, total=  18.5s
# [CV] max_features=log2, n_estimators=860 .............................
# [CV] . max_features=log2, n_estimators=860, score=0.769, total=  19.6s
# [CV] max_features=log2, n_estimators=860 .............................
# [CV] . max_features=log2, n_estimators=860, score=0.749, total=  24.5s
# [CV] max_features=log2, n_estimators=860 .............................
# [CV] . max_features=log2, n_estimators=860, score=0.749, total=  20.1s
# [CV] max_features=log2, n_estimators=860 .............................
# [CV] . max_features=log2, n_estimators=860, score=0.768, total=  18.4s
# [CV] max_features=log2, n_estimators=870 .............................
# [CV] . max_features=log2, n_estimators=870, score=0.771, total=  20.4s
# [CV] max_features=log2, n_estimators=870 .............................
# [CV] . max_features=log2, n_estimators=870, score=0.762, total=  19.2s
# [CV] max_features=log2, n_estimators=870 .............................
# [CV] . max_features=log2, n_estimators=870, score=0.746, total=  18.8s
# [CV] max_features=log2, n_estimators=870 .............................
# [CV] . max_features=log2, n_estimators=870, score=0.752, total=  18.9s
# [CV] max_features=log2, n_estimators=870 .............................
# [CV] . max_features=log2, n_estimators=870, score=0.763, total=  19.1s
# [CV] max_features=log2, n_estimators=880 .............................
# [CV] . max_features=log2, n_estimators=880, score=0.772, total=  19.2s
# [CV] max_features=log2, n_estimators=880 .............................
# [CV] . max_features=log2, n_estimators=880, score=0.773, total=  19.0s
# [CV] max_features=log2, n_estimators=880 .............................
# [CV] . max_features=log2, n_estimators=880, score=0.745, total=  18.8s
# [CV] max_features=log2, n_estimators=880 .............................
# [CV] . max_features=log2, n_estimators=880, score=0.757, total=  19.2s
# [CV] max_features=log2, n_estimators=880 .............................
# [CV] . max_features=log2, n_estimators=880, score=0.766, total=  19.3s
# [CV] max_features=log2, n_estimators=890 .............................
# [CV] . max_features=log2, n_estimators=890, score=0.776, total=  19.8s
# [CV] max_features=log2, n_estimators=890 .............................
# [CV] . max_features=log2, n_estimators=890, score=0.766, total=  19.0s
# [CV] max_features=log2, n_estimators=890 .............................
# [CV] . max_features=log2, n_estimators=890, score=0.748, total=  19.2s
# [CV] max_features=log2, n_estimators=890 .............................
# [CV] . max_features=log2, n_estimators=890, score=0.751, total=  19.7s
# [CV] max_features=log2, n_estimators=890 .............................
# [CV] . max_features=log2, n_estimators=890, score=0.764, total=  19.3s
# [CV] max_features=log2, n_estimators=900 .............................
# [CV] . max_features=log2, n_estimators=900, score=0.774, total=  19.5s
# [CV] max_features=log2, n_estimators=900 .............................
# [CV] . max_features=log2, n_estimators=900, score=0.768, total=  19.9s
# [CV] max_features=log2, n_estimators=900 .............................
# [CV] . max_features=log2, n_estimators=900, score=0.747, total=  20.4s
# [CV] max_features=log2, n_estimators=900 .............................
# [CV] . max_features=log2, n_estimators=900, score=0.760, total=  19.3s
# [CV] max_features=log2, n_estimators=900 .............................
# [CV] . max_features=log2, n_estimators=900, score=0.763, total=  19.7s
# [CV] max_features=log2, n_estimators=910 .............................
# [CV] . max_features=log2, n_estimators=910, score=0.778, total=  19.8s
# [CV] max_features=log2, n_estimators=910 .............................
# [CV] . max_features=log2, n_estimators=910, score=0.765, total=  19.8s
# [CV] max_features=log2, n_estimators=910 .............................
# [CV] . max_features=log2, n_estimators=910, score=0.750, total=  19.8s
# [CV] max_features=log2, n_estimators=910 .............................
# [CV] . max_features=log2, n_estimators=910, score=0.754, total=  19.5s
# [CV] max_features=log2, n_estimators=910 .............................
# [CV] . max_features=log2, n_estimators=910, score=0.764, total=  20.2s
# [CV] max_features=log2, n_estimators=920 .............................
# [CV] . max_features=log2, n_estimators=920, score=0.771, total=  20.1s
# [CV] max_features=log2, n_estimators=920 .............................
# [CV] . max_features=log2, n_estimators=920, score=0.767, total=  19.9s
# [CV] max_features=log2, n_estimators=920 .............................
# [CV] . max_features=log2, n_estimators=920, score=0.747, total=  25.5s
# [CV] max_features=log2, n_estimators=920 .............................
# [CV] . max_features=log2, n_estimators=920, score=0.758, total=  21.2s
# [CV] max_features=log2, n_estimators=920 .............................
# [CV] . max_features=log2, n_estimators=920, score=0.762, total=  20.1s
# [CV] max_features=log2, n_estimators=930 .............................
# [CV] . max_features=log2, n_estimators=930, score=0.772, total=  20.4s
# [CV] max_features=log2, n_estimators=930 .............................
# [CV] . max_features=log2, n_estimators=930, score=0.767, total=  20.3s
# [CV] max_features=log2, n_estimators=930 .............................
# [CV] . max_features=log2, n_estimators=930, score=0.747, total=  20.4s
# [CV] max_features=log2, n_estimators=930 .............................
# [CV] . max_features=log2, n_estimators=930, score=0.756, total=  20.1s
# [CV] max_features=log2, n_estimators=930 .............................
# [CV] . max_features=log2, n_estimators=930, score=0.763, total=  20.0s
# [CV] max_features=log2, n_estimators=940 .............................
# [CV] . max_features=log2, n_estimators=940, score=0.772, total=  20.2s
# [CV] max_features=log2, n_estimators=940 .............................
# [CV] . max_features=log2, n_estimators=940, score=0.765, total=  20.4s
# [CV] max_features=log2, n_estimators=940 .............................
# [CV] . max_features=log2, n_estimators=940, score=0.746, total=  20.9s
# [CV] max_features=log2, n_estimators=940 .............................
# [CV] . max_features=log2, n_estimators=940, score=0.759, total=  20.3s
# [CV] max_features=log2, n_estimators=940 .............................
# [CV] . max_features=log2, n_estimators=940, score=0.763, total=  20.2s
# [CV] max_features=log2, n_estimators=950 .............................
# [CV] . max_features=log2, n_estimators=950, score=0.772, total=  20.8s
# [CV] max_features=log2, n_estimators=950 .............................
# [CV] . max_features=log2, n_estimators=950, score=0.764, total=  20.3s
# [CV] max_features=log2, n_estimators=950 .............................
# [CV] . max_features=log2, n_estimators=950, score=0.745, total=  20.7s
# [CV] max_features=log2, n_estimators=950 .............................
# [CV] . max_features=log2, n_estimators=950, score=0.753, total=  20.8s
# [CV] max_features=log2, n_estimators=950 .............................
# [CV] . max_features=log2, n_estimators=950, score=0.767, total=  20.7s
# [CV] max_features=log2, n_estimators=960 .............................
# [CV] . max_features=log2, n_estimators=960, score=0.773, total=  21.0s
# [CV] max_features=log2, n_estimators=960 .............................
# [CV] . max_features=log2, n_estimators=960, score=0.760, total=  21.0s
# [CV] max_features=log2, n_estimators=960 .............................
# [CV] . max_features=log2, n_estimators=960, score=0.748, total=  20.6s
# [CV] max_features=log2, n_estimators=960 .............................
# [CV] . max_features=log2, n_estimators=960, score=0.754, total=  21.0s
# [CV] max_features=log2, n_estimators=960 .............................
# [CV] . max_features=log2, n_estimators=960, score=0.759, total=  20.8s
# [CV] max_features=log2, n_estimators=970 .............................
# [CV] . max_features=log2, n_estimators=970, score=0.772, total=  21.2s
# [CV] max_features=log2, n_estimators=970 .............................
# [CV] . max_features=log2, n_estimators=970, score=0.765, total=  22.1s
# [CV] max_features=log2, n_estimators=970 .............................
# [CV] . max_features=log2, n_estimators=970, score=0.748, total=  20.7s
# [CV] max_features=log2, n_estimators=970 .............................
# [CV] . max_features=log2, n_estimators=970, score=0.758, total=  20.7s
# [CV] max_features=log2, n_estimators=970 .............................
# [CV] . max_features=log2, n_estimators=970, score=0.764, total=  22.3s
# [CV] max_features=log2, n_estimators=980 .............................
# [CV] . max_features=log2, n_estimators=980, score=0.772, total=  24.9s
# [CV] max_features=log2, n_estimators=980 .............................
# [CV] . max_features=log2, n_estimators=980, score=0.760, total=  25.2s
# [CV] max_features=log2, n_estimators=980 .............................
# [CV] . max_features=log2, n_estimators=980, score=0.745, total=  21.5s
# [CV] max_features=log2, n_estimators=980 .............................
# [CV] . max_features=log2, n_estimators=980, score=0.750, total=  22.3s
# [CV] max_features=log2, n_estimators=980 .............................
# [CV] . max_features=log2, n_estimators=980, score=0.761, total=  21.4s
# [CV] max_features=log2, n_estimators=990 .............................
# [CV] . max_features=log2, n_estimators=990, score=0.779, total=  21.5s
# [CV] max_features=log2, n_estimators=990 .............................
# [CV] . max_features=log2, n_estimators=990, score=0.764, total=  21.8s
# [CV] max_features=log2, n_estimators=990 .............................
# [CV] . max_features=log2, n_estimators=990, score=0.746, total=  21.7s
# [CV] max_features=log2, n_estimators=990 .............................
# [CV] . max_features=log2, n_estimators=990, score=0.757, total=  22.0s
# [CV] max_features=log2, n_estimators=990 .............................
# [CV] . max_features=log2, n_estimators=990, score=0.761, total=  21.6s
# [Parallel(n_jobs=1)]: Done 1350 out of 1350 | elapsed: 278.4min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=1900, n_jobs=None...
#        230, 240, 250, 260, 270, 280, 290, 300, 310, 320, 330, 340, 350,
#        360, 370, 380, 390, 400, 410, 420, 430, 440, 450, 460, 470, 480,
#        490, 500, 510, 520, 530, 540, 550, 560, 570, 580, 590, 600, 610,
#        620, 630, 640, 650, 660, 670, 680, 690, 700, 710, 720, 730, 740,
#        750, 760, 770, 780, 790, 800, 810, 820, 830, 840, 850, 860, 870,
#        880, 890, 900, 910, 920, 930, 940, 950, 960, 970, 980, 990])},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'max_features': 'log2', 'n_estimators': 260}
# 0.765780568916962

# %%
model_final = RandomForestClassifier(n_estimators=260, max_features='log2')
model_final.fit(X_train, y_train)

print(f'''
Training Score: {model_final.score(X_train, y_train)}
Testing Score: {model_final.score(X_test, y_test)}
''')
# Out:
# Training Score: 1.0
# Testing Score: 0.7551487414187643

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'random_forest_model_exoplanets.h5'
joblib.dump(model_final, filename)
# Out:
# ['random_forest_model_exoplanets.h5']
