# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = df[
    ['koi_period', 
     'koi_time0bk', 
     #'koi_impact', 
     'koi_duration', 
     'koi_depth',
     'koi_prad',
     'koi_teq',
     'koi_insol',
     #'koi_model_snr',
     #'koi_steff',
     #'koi_slogg',
     #'koi_srad',
     'ra',
     'dec',
     'koi_kepmag'
    ]
]

# %%
y = df.koi_disposition.values.reshape(-1,1)
print(y)
# Out:
# [['CONFIRMED']
#  ['FALSE POSITIVE']
#  ['FALSE POSITIVE']
#  ...
#  ['CANDIDATE']
#  ['FALSE POSITIVE']
#  ['FALSE POSITIVE']]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split
X = selected_features.copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train.head()
# Out:
#       koi_period  koi_time0bk  koi_duration  koi_depth  koi_prad  koi_teq  \
# 6122    6.768901   133.077240       3.61600      123.1      1.24     1017
# 6370    0.733726   132.020050       2.30900      114.6      0.86     1867
# 2879    7.652707   134.460380      79.89690      641.1      3.21      989
# 107     7.953547   174.662240       2.63120      875.4      2.25      696
# 29      4.959319   172.258529       2.22739     9802.0     12.21     1103
#
#       koi_insol         ra        dec  koi_kepmag
# 6122     253.30  294.40472  39.351681      14.725
# 6370    2891.64  284.50391  42.463860      15.770
# 2879     226.81  295.50211  38.983540      13.099
# 107       55.37  291.15878  40.750271      15.660
# 29       349.40  292.16705  48.727589      15.263

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import StandardScaler, MinMaxScaler
X_scaler = MinMaxScaler(feature_range=(0,1))
# y_train_scaler = MinMaxScaler(y_train)

X_train_scaled =  X_scaler.fit_transform(X_train)
print(X_train_scaled)
X_test_scaled = X_scaler.fit_transform(X_test)
# Out:
# [[8.04827937e-03 9.29087782e-03 2.49253828e-02 ... 6.65745671e-01
#   1.76049579e-01 6.41292669e-01]
#  [5.85971231e-04 8.50893625e-03 1.54798985e-02 ... 2.12684670e-01
#   3.73540046e-01 7.27663443e-01]
#  [9.14107928e-03 1.03139055e-02 5.76195501e-01 ... 7.15962230e-01
#   1.52688346e-01 5.06901397e-01]
#  ...
#  [7.28333836e-03 1.02861285e-02 1.10009178e-02 ... 7.92823003e-01
#   5.97200429e-01 3.02173733e-01]
#  [3.81261085e-03 1.05984604e-02 1.96013673e-01 ... 7.78217328e-01
#   2.90002258e-01 5.21530705e-01]
#  [2.48788464e-03 1.05640079e-02 3.76952151e-02 ... 6.80822216e-01
#   2.71853535e-01 6.19307381e-01]]

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=200)
model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# # Train the Model

# %%
# print(f"Training Data Score: {model.score(X_train_scaled, y_train)}")
# print(f"Testing Data Score: {model.score(X_test_scaled, y_test)}")

print(f"Training Data Score: {model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.683066361556064

# %%
# scores = []
# This was for my own enjoyment
# for i in range(100,2000,100):
#     model = RandomForestClassifier(n_estimators=i)
#     model.fit(X_train, y_train)
#     print(f'Number of estimators: {i}')
#     print(f"Training Data Score: {model.score(X_train, y_train)}")
# #     model.score(X_train, y_train)
#     print(f"Testing Data Score: {model.score(X_test, y_test)}")
#     print('\n------------')
# #     score = model.score(X_test, y_test)

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
X_train_scaled
# Out:
# array([[8.04827937e-03, 9.29087782e-03, 2.49253828e-02, ...,
#         6.65745671e-01, 1.76049579e-01, 6.41292669e-01],
#        [5.85971231e-04, 8.50893625e-03, 1.54798985e-02, ...,
#         2.12684670e-01, 3.73540046e-01, 7.27663443e-01],
#        [9.14107928e-03, 1.03139055e-02, 5.76195501e-01, ...,
#         7.15962230e-01, 1.52688346e-01, 5.06901397e-01],
#        ...,
#        [7.28333836e-03, 1.02861285e-02, 1.10009178e-02, ...,
#         7.92823003e-01, 5.97200429e-01, 3.02173733e-01],
#        [3.81261085e-03, 1.05984604e-02, 1.96013673e-01, ...,
#         7.78217328e-01, 2.90002258e-01, 5.21530705e-01],
#        [2.48788464e-03, 1.05640079e-02, 3.76952151e-02, ...,
#         6.80822216e-01, 2.71853535e-01, 6.19307381e-01]])

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
import numpy as np
param_grid = {'n_estimators': np.arange(100,300,10),
              'max_features': ['auto', 'sqrt', 'log2']}
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled,y_train)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [CV] max_features=auto, n_estimators=100 .............................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] . max_features=auto, n_estimators=100, score=0.751, total=   1.9s
# [CV] max_features=auto, n_estimators=100 .............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [CV] . max_features=auto, n_estimators=100, score=0.737, total=   1.9s
# [CV] max_features=auto, n_estimators=100 .............................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.6s remaining:    0.0s
# [CV] . max_features=auto, n_estimators=100, score=0.721, total=   1.6s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] . max_features=auto, n_estimators=100, score=0.703, total=   1.8s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] . max_features=auto, n_estimators=100, score=0.739, total=   1.9s
# [CV] max_features=auto, n_estimators=110 .............................
# [CV] . max_features=auto, n_estimators=110, score=0.740, total=   1.7s
# [CV] max_features=auto, n_estimators=110 .............................
# [CV] . max_features=auto, n_estimators=110, score=0.730, total=   3.6s
# [CV] max_features=auto, n_estimators=110 .............................
# [CV] . max_features=auto, n_estimators=110, score=0.714, total=   2.3s
# [CV] max_features=auto, n_estimators=110 .............................
# [CV] . max_features=auto, n_estimators=110, score=0.718, total=   1.9s
# [CV] max_features=auto, n_estimators=110 .............................
# [CV] . max_features=auto, n_estimators=110, score=0.732, total=   1.4s
# [CV] max_features=auto, n_estimators=120 .............................
# [CV] . max_features=auto, n_estimators=120, score=0.740, total=   1.6s
# [CV] max_features=auto, n_estimators=120 .............................
# [CV] . max_features=auto, n_estimators=120, score=0.731, total=   1.8s
# [CV] max_features=auto, n_estimators=120 .............................
# [CV] . max_features=auto, n_estimators=120, score=0.727, total=   1.6s
# [CV] max_features=auto, n_estimators=120 .............................
# [CV] . max_features=auto, n_estimators=120, score=0.713, total=   1.6s
# [CV] max_features=auto, n_estimators=120 .............................
# [CV] . max_features=auto, n_estimators=120, score=0.736, total=   1.8s
# [CV] max_features=auto, n_estimators=130 .............................
# [CV] . max_features=auto, n_estimators=130, score=0.745, total=   1.7s
# [CV] max_features=auto, n_estimators=130 .............................
# [CV] . max_features=auto, n_estimators=130, score=0.732, total=   1.8s
# [CV] max_features=auto, n_estimators=130 .............................
# [CV] . max_features=auto, n_estimators=130, score=0.721, total=   1.9s
# [CV] max_features=auto, n_estimators=130 .............................
# [CV] . max_features=auto, n_estimators=130, score=0.718, total=   1.6s
# [CV] max_features=auto, n_estimators=130 .............................
# [CV] . max_features=auto, n_estimators=130, score=0.735, total=   1.8s
# [CV] max_features=auto, n_estimators=140 .............................
# [CV] . max_features=auto, n_estimators=140, score=0.736, total=   2.1s
# [CV] max_features=auto, n_estimators=140 .............................
# [CV] . max_features=auto, n_estimators=140, score=0.732, total=   1.7s
# [CV] max_features=auto, n_estimators=140 .............................
# [CV] . max_features=auto, n_estimators=140, score=0.724, total=   2.2s
# [CV] max_features=auto, n_estimators=140 .............................
# [CV] . max_features=auto, n_estimators=140, score=0.722, total=   2.0s
# [CV] max_features=auto, n_estimators=140 .............................
# [CV] . max_features=auto, n_estimators=140, score=0.736, total=   1.9s
# [CV] max_features=auto, n_estimators=150 .............................
# [CV] . max_features=auto, n_estimators=150, score=0.747, total=   2.2s
# [CV] max_features=auto, n_estimators=150 .............................
# [CV] . max_features=auto, n_estimators=150, score=0.736, total=   1.9s
# [CV] max_features=auto, n_estimators=150 .............................
# [CV] . max_features=auto, n_estimators=150, score=0.726, total=   2.3s
# [CV] max_features=auto, n_estimators=150 .............................
# [CV] . max_features=auto, n_estimators=150, score=0.703, total=   1.9s
# [CV] max_features=auto, n_estimators=150 .............................
# [CV] . max_features=auto, n_estimators=150, score=0.729, total=   2.1s
# [CV] max_features=auto, n_estimators=160 .............................
# [CV] . max_features=auto, n_estimators=160, score=0.743, total=   2.3s
# [CV] max_features=auto, n_estimators=160 .............................
# [CV] . max_features=auto, n_estimators=160, score=0.729, total=   2.2s
# [CV] max_features=auto, n_estimators=160 .............................
# [CV] . max_features=auto, n_estimators=160, score=0.725, total=   2.3s
# [CV] max_features=auto, n_estimators=160 .............................
# [CV] . max_features=auto, n_estimators=160, score=0.709, total=   2.0s
# [CV] max_features=auto, n_estimators=160 .............................
# [CV] . max_features=auto, n_estimators=160, score=0.737, total=   2.5s
# [CV] max_features=auto, n_estimators=170 .............................
# [CV] . max_features=auto, n_estimators=170, score=0.744, total=   2.1s
# [CV] max_features=auto, n_estimators=170 .............................
# [CV] . max_features=auto, n_estimators=170, score=0.744, total=   3.3s
# [CV] max_features=auto, n_estimators=170 .............................
# [CV] . max_features=auto, n_estimators=170, score=0.726, total=   2.3s
# [CV] max_features=auto, n_estimators=170 .............................
# [CV] . max_features=auto, n_estimators=170, score=0.717, total=   2.6s
# [CV] max_features=auto, n_estimators=170 .............................
# [CV] . max_features=auto, n_estimators=170, score=0.738, total=   2.1s
# [CV] max_features=auto, n_estimators=180 .............................
# [CV] . max_features=auto, n_estimators=180, score=0.748, total=   2.8s
# [CV] max_features=auto, n_estimators=180 .............................
# [CV] . max_features=auto, n_estimators=180, score=0.731, total=   2.2s
# [CV] max_features=auto, n_estimators=180 .............................
# [CV] . max_features=auto, n_estimators=180, score=0.716, total=   2.8s
# [CV] max_features=auto, n_estimators=180 .............................
# [CV] . max_features=auto, n_estimators=180, score=0.709, total=   2.2s
# [CV] max_features=auto, n_estimators=180 .............................
# [CV] . max_features=auto, n_estimators=180, score=0.735, total=   2.8s
# [CV] max_features=auto, n_estimators=190 .............................
# [CV] . max_features=auto, n_estimators=190, score=0.745, total=   2.5s
# [CV] max_features=auto, n_estimators=190 .............................
# [CV] . max_features=auto, n_estimators=190, score=0.727, total=   2.8s
# [CV] max_features=auto, n_estimators=190 .............................
# [CV] . max_features=auto, n_estimators=190, score=0.723, total=   2.5s
# [CV] max_features=auto, n_estimators=190 .............................
# [CV] . max_features=auto, n_estimators=190, score=0.712, total=   2.8s
# [CV] max_features=auto, n_estimators=190 .............................
# [CV] . max_features=auto, n_estimators=190, score=0.733, total=   2.6s
# [CV] max_features=auto, n_estimators=200 .............................
# [CV] . max_features=auto, n_estimators=200, score=0.743, total=   2.8s
# [CV] max_features=auto, n_estimators=200 .............................
# [CV] . max_features=auto, n_estimators=200, score=0.730, total=   2.8s
# [CV] max_features=auto, n_estimators=200 .............................
# [CV] . max_features=auto, n_estimators=200, score=0.733, total=   2.6s
# [CV] max_features=auto, n_estimators=200 .............................
# [CV] . max_features=auto, n_estimators=200, score=0.713, total=   2.9s
# [CV] max_features=auto, n_estimators=200 .............................
# [CV] . max_features=auto, n_estimators=200, score=0.729, total=   2.6s
# [CV] max_features=auto, n_estimators=210 .............................
# [CV] . max_features=auto, n_estimators=210, score=0.740, total=   3.1s
# [CV] max_features=auto, n_estimators=210 .............................
# [CV] . max_features=auto, n_estimators=210, score=0.726, total=   2.8s
# [CV] max_features=auto, n_estimators=210 .............................
# [CV] . max_features=auto, n_estimators=210, score=0.730, total=   2.9s
# [CV] max_features=auto, n_estimators=210 .............................
# [CV] . max_features=auto, n_estimators=210, score=0.710, total=   2.9s
# [CV] max_features=auto, n_estimators=210 .............................
# [CV] . max_features=auto, n_estimators=210, score=0.738, total=   2.9s
# [CV] max_features=auto, n_estimators=220 .............................
# [CV] . max_features=auto, n_estimators=220, score=0.745, total=   3.3s
# [CV] max_features=auto, n_estimators=220 .............................
# [CV] . max_features=auto, n_estimators=220, score=0.737, total=   2.9s
# [CV] max_features=auto, n_estimators=220 .............................
# [CV] . max_features=auto, n_estimators=220, score=0.725, total=   3.1s
# [CV] max_features=auto, n_estimators=220 .............................
# [CV] . max_features=auto, n_estimators=220, score=0.722, total=   3.0s
# [CV] max_features=auto, n_estimators=220 .............................
# [CV] . max_features=auto, n_estimators=220, score=0.733, total=   3.0s
# [CV] max_features=auto, n_estimators=230 .............................
# [CV] . max_features=auto, n_estimators=230, score=0.746, total=   3.5s
# [CV] max_features=auto, n_estimators=230 .............................
# [CV] . max_features=auto, n_estimators=230, score=0.745, total=   3.2s
# [CV] max_features=auto, n_estimators=230 .............................
# [CV] . max_features=auto, n_estimators=230, score=0.730, total=   3.0s
# [CV] max_features=auto, n_estimators=230 .............................
# [CV] . max_features=auto, n_estimators=230, score=0.717, total=   3.3s
# [CV] max_features=auto, n_estimators=230 .............................
# [CV] . max_features=auto, n_estimators=230, score=0.728, total=   3.0s
# [CV] max_features=auto, n_estimators=240 .............................
# [CV] . max_features=auto, n_estimators=240, score=0.746, total=   3.3s
# [CV] max_features=auto, n_estimators=240 .............................
# [CV] . max_features=auto, n_estimators=240, score=0.731, total=   3.5s
# [CV] max_features=auto, n_estimators=240 .............................
# [CV] . max_features=auto, n_estimators=240, score=0.726, total=   3.2s
# [CV] max_features=auto, n_estimators=240 .............................
# [CV] . max_features=auto, n_estimators=240, score=0.716, total=   3.4s
# [CV] max_features=auto, n_estimators=240 .............................
# [CV] . max_features=auto, n_estimators=240, score=0.740, total=   3.5s
# [CV] max_features=auto, n_estimators=250 .............................
# [CV] . max_features=auto, n_estimators=250, score=0.745, total=   3.3s
# [CV] max_features=auto, n_estimators=250 .............................
# [CV] . max_features=auto, n_estimators=250, score=0.738, total=   3.5s
# [CV] max_features=auto, n_estimators=250 .............................
# [CV] . max_features=auto, n_estimators=250, score=0.730, total=   3.6s
# [CV] max_features=auto, n_estimators=250 .............................
# [CV] . max_features=auto, n_estimators=250, score=0.713, total=   3.4s
# [CV] max_features=auto, n_estimators=250 .............................
# [CV] . max_features=auto, n_estimators=250, score=0.731, total=   3.3s
# [CV] max_features=auto, n_estimators=260 .............................
# [CV] . max_features=auto, n_estimators=260, score=0.747, total=   3.7s
# [CV] max_features=auto, n_estimators=260 .............................
# [CV] . max_features=auto, n_estimators=260, score=0.741, total=   3.7s
# [CV] max_features=auto, n_estimators=260 .............................
# [CV] . max_features=auto, n_estimators=260, score=0.729, total=   3.4s
# [CV] max_features=auto, n_estimators=260 .............................
# [CV] . max_features=auto, n_estimators=260, score=0.711, total=   3.5s
# [CV] max_features=auto, n_estimators=260 .............................
# [CV] . max_features=auto, n_estimators=260, score=0.735, total=   3.7s
# [CV] max_features=auto, n_estimators=270 .............................
# [CV] . max_features=auto, n_estimators=270, score=0.747, total=   3.7s
# [CV] max_features=auto, n_estimators=270 .............................
# [CV] . max_features=auto, n_estimators=270, score=0.731, total=   3.8s
# [CV] max_features=auto, n_estimators=270 .............................
# [CV] . max_features=auto, n_estimators=270, score=0.717, total=   3.7s
# [CV] max_features=auto, n_estimators=270 .............................
# [CV] . max_features=auto, n_estimators=270, score=0.711, total=   3.8s
# [CV] max_features=auto, n_estimators=270 .............................
# [CV] . max_features=auto, n_estimators=270, score=0.739, total=   3.7s
# [CV] max_features=auto, n_estimators=280 .............................
# [CV] . max_features=auto, n_estimators=280, score=0.754, total=   3.8s
# [CV] max_features=auto, n_estimators=280 .............................
# [CV] . max_features=auto, n_estimators=280, score=0.735, total=   3.8s
# [CV] max_features=auto, n_estimators=280 .............................
# [CV] . max_features=auto, n_estimators=280, score=0.733, total=   4.0s
# [CV] max_features=auto, n_estimators=280 .............................
# [CV] . max_features=auto, n_estimators=280, score=0.719, total=   3.9s
# [CV] max_features=auto, n_estimators=280 .............................
# [CV] . max_features=auto, n_estimators=280, score=0.734, total=   3.9s
# [CV] max_features=auto, n_estimators=290 .............................
# [CV] . max_features=auto, n_estimators=290, score=0.742, total=   4.2s
# [CV] max_features=auto, n_estimators=290 .............................
# [CV] . max_features=auto, n_estimators=290, score=0.735, total=   4.0s
# [CV] max_features=auto, n_estimators=290 .............................
# [CV] . max_features=auto, n_estimators=290, score=0.726, total=   4.1s
# [CV] max_features=auto, n_estimators=290 .............................
# [CV] . max_features=auto, n_estimators=290, score=0.712, total=   4.6s
# [CV] max_features=auto, n_estimators=290 .............................
# [CV] . max_features=auto, n_estimators=290, score=0.736, total=   4.0s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] . max_features=sqrt, n_estimators=100, score=0.741, total=   1.4s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] . max_features=sqrt, n_estimators=100, score=0.726, total=   1.2s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] . max_features=sqrt, n_estimators=100, score=0.732, total=   1.4s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] . max_features=sqrt, n_estimators=100, score=0.712, total=   1.6s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] . max_features=sqrt, n_estimators=100, score=0.732, total=   1.2s
# [CV] max_features=sqrt, n_estimators=110 .............................
# [CV] . max_features=sqrt, n_estimators=110, score=0.739, total=   1.5s
# [CV] max_features=sqrt, n_estimators=110 .............................
# [CV] . max_features=sqrt, n_estimators=110, score=0.732, total=   1.6s
# [CV] max_features=sqrt, n_estimators=110 .............................
# [CV] . max_features=sqrt, n_estimators=110, score=0.740, total=   1.5s
# [CV] max_features=sqrt, n_estimators=110 .............................
# [CV] . max_features=sqrt, n_estimators=110, score=0.699, total=   1.3s
# [CV] max_features=sqrt, n_estimators=110 .............................
# [CV] . max_features=sqrt, n_estimators=110, score=0.729, total=   1.7s
# [CV] max_features=sqrt, n_estimators=120 .............................
# [CV] . max_features=sqrt, n_estimators=120, score=0.747, total=   1.7s
# [CV] max_features=sqrt, n_estimators=120 .............................
# [CV] . max_features=sqrt, n_estimators=120, score=0.739, total=   1.5s
# [CV] max_features=sqrt, n_estimators=120 .............................
# [CV] . max_features=sqrt, n_estimators=120, score=0.724, total=   1.8s
# [CV] max_features=sqrt, n_estimators=120 .............................
# [CV] . max_features=sqrt, n_estimators=120, score=0.701, total=   1.7s
# [CV] max_features=sqrt, n_estimators=120 .............................
# [CV] . max_features=sqrt, n_estimators=120, score=0.747, total=   1.5s
# [CV] max_features=sqrt, n_estimators=130 .............................
# [CV] . max_features=sqrt, n_estimators=130, score=0.739, total=   1.9s
# [CV] max_features=sqrt, n_estimators=130 .............................
# [CV] . max_features=sqrt, n_estimators=130, score=0.737, total=   1.8s
# [CV] max_features=sqrt, n_estimators=130 .............................
# [CV] . max_features=sqrt, n_estimators=130, score=0.718, total=   1.7s
# [CV] max_features=sqrt, n_estimators=130 .............................
# [CV] . max_features=sqrt, n_estimators=130, score=0.712, total=   2.0s
# [CV] max_features=sqrt, n_estimators=130 .............................
# [CV] . max_features=sqrt, n_estimators=130, score=0.739, total=   1.7s
# [CV] max_features=sqrt, n_estimators=140 .............................
# [CV] . max_features=sqrt, n_estimators=140, score=0.750, total=   2.1s
# [CV] max_features=sqrt, n_estimators=140 .............................
# [CV] . max_features=sqrt, n_estimators=140, score=0.727, total=   2.1s
# [CV] max_features=sqrt, n_estimators=140 .............................
# [CV] . max_features=sqrt, n_estimators=140, score=0.718, total=   1.8s
# [CV] max_features=sqrt, n_estimators=140 .............................
# [CV] . max_features=sqrt, n_estimators=140, score=0.713, total=   2.1s
# [CV] max_features=sqrt, n_estimators=140 .............................
# [CV] . max_features=sqrt, n_estimators=140, score=0.729, total=   1.9s
# [CV] max_features=sqrt, n_estimators=150 .............................
# [CV] . max_features=sqrt, n_estimators=150, score=0.746, total=   2.0s
# [CV] max_features=sqrt, n_estimators=150 .............................
# [CV] . max_features=sqrt, n_estimators=150, score=0.731, total=   2.2s
# [CV] max_features=sqrt, n_estimators=150 .............................
# [CV] . max_features=sqrt, n_estimators=150, score=0.718, total=   1.9s
# [CV] max_features=sqrt, n_estimators=150 .............................
# [CV] . max_features=sqrt, n_estimators=150, score=0.715, total=   2.3s
# [CV] max_features=sqrt, n_estimators=150 .............................
# [CV] . max_features=sqrt, n_estimators=150, score=0.731, total=   1.9s
# [CV] max_features=sqrt, n_estimators=160 .............................
# [CV] . max_features=sqrt, n_estimators=160, score=0.745, total=   2.3s
# [CV] max_features=sqrt, n_estimators=160 .............................
# [CV] . max_features=sqrt, n_estimators=160, score=0.736, total=   2.2s
# [CV] max_features=sqrt, n_estimators=160 .............................
# [CV] . max_features=sqrt, n_estimators=160, score=0.726, total=   2.1s
# [CV] max_features=sqrt, n_estimators=160 .............................
# [CV] . max_features=sqrt, n_estimators=160, score=0.708, total=   2.3s
# [CV] max_features=sqrt, n_estimators=160 .............................
# [CV] . max_features=sqrt, n_estimators=160, score=0.733, total=   2.1s
# [CV] max_features=sqrt, n_estimators=170 .............................
# [CV] . max_features=sqrt, n_estimators=170, score=0.742, total=   2.6s
# [CV] max_features=sqrt, n_estimators=170 .............................
# [CV] . max_features=sqrt, n_estimators=170, score=0.734, total=   2.7s
# [CV] max_features=sqrt, n_estimators=170 .............................
# [CV] . max_features=sqrt, n_estimators=170, score=0.725, total=   2.5s
# [CV] max_features=sqrt, n_estimators=170 .............................
# [CV] . max_features=sqrt, n_estimators=170, score=0.715, total=   2.2s
# [CV] max_features=sqrt, n_estimators=170 .............................
# [CV] . max_features=sqrt, n_estimators=170, score=0.740, total=   2.5s
# [CV] max_features=sqrt, n_estimators=180 .............................
# [CV] . max_features=sqrt, n_estimators=180, score=0.747, total=   2.3s
# [CV] max_features=sqrt, n_estimators=180 .............................
# [CV] . max_features=sqrt, n_estimators=180, score=0.740, total=   2.7s
# [CV] max_features=sqrt, n_estimators=180 .............................
# [CV] . max_features=sqrt, n_estimators=180, score=0.724, total=   2.2s
# [CV] max_features=sqrt, n_estimators=180 .............................
# [CV] . max_features=sqrt, n_estimators=180, score=0.713, total=   2.7s
# [CV] max_features=sqrt, n_estimators=180 .............................
# [CV] . max_features=sqrt, n_estimators=180, score=0.737, total=   2.3s
# [CV] max_features=sqrt, n_estimators=190 .............................
# [CV] . max_features=sqrt, n_estimators=190, score=0.745, total=   2.9s
# [CV] max_features=sqrt, n_estimators=190 .............................
# [CV] . max_features=sqrt, n_estimators=190, score=0.735, total=   2.6s
# [CV] max_features=sqrt, n_estimators=190 .............................
# [CV] . max_features=sqrt, n_estimators=190, score=0.727, total=   2.7s
# [CV] max_features=sqrt, n_estimators=190 .............................
# [CV] . max_features=sqrt, n_estimators=190, score=0.704, total=   2.5s
# [CV] max_features=sqrt, n_estimators=190 .............................
# [CV] . max_features=sqrt, n_estimators=190, score=0.741, total=   2.7s
# [CV] max_features=sqrt, n_estimators=200 .............................
# [CV] . max_features=sqrt, n_estimators=200, score=0.738, total=   2.6s
# [CV] max_features=sqrt, n_estimators=200 .............................
# [CV] . max_features=sqrt, n_estimators=200, score=0.727, total=   2.8s
# [CV] max_features=sqrt, n_estimators=200 .............................
# [CV] . max_features=sqrt, n_estimators=200, score=0.725, total=   2.8s
# [CV] max_features=sqrt, n_estimators=200 .............................
# [CV] . max_features=sqrt, n_estimators=200, score=0.722, total=   3.0s
# [CV] max_features=sqrt, n_estimators=200 .............................
# [CV] . max_features=sqrt, n_estimators=200, score=0.738, total=   3.0s
# [CV] max_features=sqrt, n_estimators=210 .............................
# [CV] . max_features=sqrt, n_estimators=210, score=0.750, total=   2.8s
# [CV] max_features=sqrt, n_estimators=210 .............................
# [CV] . max_features=sqrt, n_estimators=210, score=0.728, total=   2.9s
# [CV] max_features=sqrt, n_estimators=210 .............................
# [CV] . max_features=sqrt, n_estimators=210, score=0.726, total=   2.8s
# [CV] max_features=sqrt, n_estimators=210 .............................
# [CV] . max_features=sqrt, n_estimators=210, score=0.715, total=   2.9s
# [CV] max_features=sqrt, n_estimators=210 .............................
# [CV] . max_features=sqrt, n_estimators=210, score=0.739, total=   3.1s
# [CV] max_features=sqrt, n_estimators=220 .............................
# [CV] . max_features=sqrt, n_estimators=220, score=0.745, total=   2.8s
# [CV] max_features=sqrt, n_estimators=220 .............................
# [CV] . max_features=sqrt, n_estimators=220, score=0.733, total=   3.2s
# [CV] max_features=sqrt, n_estimators=220 .............................
# [CV] . max_features=sqrt, n_estimators=220, score=0.725, total=   3.0s
# [CV] max_features=sqrt, n_estimators=220 .............................
# [CV] . max_features=sqrt, n_estimators=220, score=0.717, total=   3.3s
# [CV] max_features=sqrt, n_estimators=220 .............................
# [CV] . max_features=sqrt, n_estimators=220, score=0.731, total=   3.2s
# [CV] max_features=sqrt, n_estimators=230 .............................
# [CV] . max_features=sqrt, n_estimators=230, score=0.749, total=   3.1s
# [CV] max_features=sqrt, n_estimators=230 .............................
# [CV] . max_features=sqrt, n_estimators=230, score=0.738, total=   3.2s
# [CV] max_features=sqrt, n_estimators=230 .............................
# [CV] . max_features=sqrt, n_estimators=230, score=0.722, total=   3.4s
# [CV] max_features=sqrt, n_estimators=230 .............................
# [CV] . max_features=sqrt, n_estimators=230, score=0.713, total=   3.0s
# [CV] max_features=sqrt, n_estimators=230 .............................
# [CV] . max_features=sqrt, n_estimators=230, score=0.732, total=   3.2s
# [CV] max_features=sqrt, n_estimators=240 .............................
# [CV] . max_features=sqrt, n_estimators=240, score=0.751, total=   3.5s
# [CV] max_features=sqrt, n_estimators=240 .............................
# [CV] . max_features=sqrt, n_estimators=240, score=0.738, total=   3.2s
# [CV] max_features=sqrt, n_estimators=240 .............................
# [CV] . max_features=sqrt, n_estimators=240, score=0.732, total=   3.3s
# [CV] max_features=sqrt, n_estimators=240 .............................
# [CV] . max_features=sqrt, n_estimators=240, score=0.719, total=   3.5s
# [CV] max_features=sqrt, n_estimators=240 .............................
# [CV] . max_features=sqrt, n_estimators=240, score=0.737, total=   3.1s
# [CV] max_features=sqrt, n_estimators=250 .............................
# [CV] . max_features=sqrt, n_estimators=250, score=0.744, total=   3.4s
# [CV] max_features=sqrt, n_estimators=250 .............................
# [CV] . max_features=sqrt, n_estimators=250, score=0.738, total=   3.6s
# [CV] max_features=sqrt, n_estimators=250 .............................
# [CV] . max_features=sqrt, n_estimators=250, score=0.727, total=   3.3s
# [CV] max_features=sqrt, n_estimators=250 .............................
# [CV] . max_features=sqrt, n_estimators=250, score=0.718, total=   3.4s
# [CV] max_features=sqrt, n_estimators=250 .............................
# [CV] . max_features=sqrt, n_estimators=250, score=0.735, total=   3.5s
# [CV] max_features=sqrt, n_estimators=260 .............................
# [CV] . max_features=sqrt, n_estimators=260, score=0.743, total=   3.4s
# [CV] max_features=sqrt, n_estimators=260 .............................
# [CV] . max_features=sqrt, n_estimators=260, score=0.740, total=   3.6s
# [CV] max_features=sqrt, n_estimators=260 .............................
# [CV] . max_features=sqrt, n_estimators=260, score=0.722, total=   3.7s
# [CV] max_features=sqrt, n_estimators=260 .............................
# [CV] . max_features=sqrt, n_estimators=260, score=0.717, total=   3.7s
# [CV] max_features=sqrt, n_estimators=260 .............................
# [CV] . max_features=sqrt, n_estimators=260, score=0.741, total=   3.4s
# [CV] max_features=sqrt, n_estimators=270 .............................
# [CV] . max_features=sqrt, n_estimators=270, score=0.748, total=   3.7s
# [CV] max_features=sqrt, n_estimators=270 .............................
# [CV] . max_features=sqrt, n_estimators=270, score=0.740, total=   3.9s
# [CV] max_features=sqrt, n_estimators=270 .............................
# [CV] . max_features=sqrt, n_estimators=270, score=0.725, total=   3.8s
# [CV] max_features=sqrt, n_estimators=270 .............................
# [CV] . max_features=sqrt, n_estimators=270, score=0.707, total=   3.7s
# [CV] max_features=sqrt, n_estimators=270 .............................
# [CV] . max_features=sqrt, n_estimators=270, score=0.737, total=   4.7s
# [CV] max_features=sqrt, n_estimators=280 .............................
# [CV] . max_features=sqrt, n_estimators=280, score=0.745, total=   5.2s
# [CV] max_features=sqrt, n_estimators=280 .............................
# [CV] . max_features=sqrt, n_estimators=280, score=0.736, total=   4.6s
# [CV] max_features=sqrt, n_estimators=280 .............................
# [CV] . max_features=sqrt, n_estimators=280, score=0.734, total=   3.8s
# [CV] max_features=sqrt, n_estimators=280 .............................
# [CV] . max_features=sqrt, n_estimators=280, score=0.715, total=   3.9s
# [CV] max_features=sqrt, n_estimators=280 .............................
# [CV] . max_features=sqrt, n_estimators=280, score=0.730, total=   3.8s
# [CV] max_features=sqrt, n_estimators=290 .............................
# [CV] . max_features=sqrt, n_estimators=290, score=0.753, total=   3.9s
# [CV] max_features=sqrt, n_estimators=290 .............................
# [CV] . max_features=sqrt, n_estimators=290, score=0.738, total=   3.9s
# [CV] max_features=sqrt, n_estimators=290 .............................
# [CV] . max_features=sqrt, n_estimators=290, score=0.721, total=   4.1s
# [CV] max_features=sqrt, n_estimators=290 .............................
# [CV] . max_features=sqrt, n_estimators=290, score=0.719, total=   4.1s
# [CV] max_features=sqrt, n_estimators=290 .............................
# [CV] . max_features=sqrt, n_estimators=290, score=0.741, total=   4.1s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] . max_features=log2, n_estimators=100, score=0.738, total=   1.4s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] . max_features=log2, n_estimators=100, score=0.731, total=   1.3s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] . max_features=log2, n_estimators=100, score=0.728, total=   1.5s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] . max_features=log2, n_estimators=100, score=0.714, total=   1.5s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] . max_features=log2, n_estimators=100, score=0.730, total=   1.3s
# [CV] max_features=log2, n_estimators=110 .............................
# [CV] . max_features=log2, n_estimators=110, score=0.741, total=   1.6s
# [CV] max_features=log2, n_estimators=110 .............................
# [CV] . max_features=log2, n_estimators=110, score=0.730, total=   1.7s
# [CV] max_features=log2, n_estimators=110 .............................
# [CV] . max_features=log2, n_estimators=110, score=0.721, total=   1.4s
# [CV] max_features=log2, n_estimators=110 .............................
# [CV] . max_features=log2, n_estimators=110, score=0.712, total=   1.5s
# [CV] max_features=log2, n_estimators=110 .............................
# [CV] . max_features=log2, n_estimators=110, score=0.745, total=   1.6s
# [CV] max_features=log2, n_estimators=120 .............................
# [CV] . max_features=log2, n_estimators=120, score=0.745, total=   1.6s
# [CV] max_features=log2, n_estimators=120 .............................
# [CV] . max_features=log2, n_estimators=120, score=0.737, total=   1.6s
# [CV] max_features=log2, n_estimators=120 .............................
# [CV] . max_features=log2, n_estimators=120, score=0.716, total=   1.8s
# [CV] max_features=log2, n_estimators=120 .............................
# [CV] . max_features=log2, n_estimators=120, score=0.714, total=   1.6s
# [CV] max_features=log2, n_estimators=120 .............................
# [CV] . max_features=log2, n_estimators=120, score=0.734, total=   1.6s
# [CV] max_features=log2, n_estimators=130 .............................
# [CV] . max_features=log2, n_estimators=130, score=0.746, total=   2.0s
# [CV] max_features=log2, n_estimators=130 .............................
# [CV] . max_features=log2, n_estimators=130, score=0.728, total=   1.6s
# [CV] max_features=log2, n_estimators=130 .............................
# [CV] . max_features=log2, n_estimators=130, score=0.722, total=   1.8s
# [CV] max_features=log2, n_estimators=130 .............................
# [CV] . max_features=log2, n_estimators=130, score=0.707, total=   2.0s
# [CV] max_features=log2, n_estimators=130 .............................
# [CV] . max_features=log2, n_estimators=130, score=0.739, total=   1.7s
# [CV] max_features=log2, n_estimators=140 .............................
# [CV] . max_features=log2, n_estimators=140, score=0.745, total=   2.1s
# [CV] max_features=log2, n_estimators=140 .............................
# [CV] . max_features=log2, n_estimators=140, score=0.726, total=   2.0s
# [CV] max_features=log2, n_estimators=140 .............................
# [CV] . max_features=log2, n_estimators=140, score=0.720, total=   2.4s
# [CV] max_features=log2, n_estimators=140 .............................
# [CV] . max_features=log2, n_estimators=140, score=0.710, total=   2.5s
# [CV] max_features=log2, n_estimators=140 .............................
# [CV] . max_features=log2, n_estimators=140, score=0.737, total=   2.4s
# [CV] max_features=log2, n_estimators=150 .............................
# [CV] . max_features=log2, n_estimators=150, score=0.743, total=   2.6s
# [CV] max_features=log2, n_estimators=150 .............................
# [CV] . max_features=log2, n_estimators=150, score=0.739, total=   2.5s
# [CV] max_features=log2, n_estimators=150 .............................
# [CV] . max_features=log2, n_estimators=150, score=0.730, total=   2.6s
# [CV] max_features=log2, n_estimators=150 .............................
# [CV] . max_features=log2, n_estimators=150, score=0.709, total=   2.7s
# [CV] max_features=log2, n_estimators=150 .............................
# [CV] . max_features=log2, n_estimators=150, score=0.726, total=   2.7s
# [CV] max_features=log2, n_estimators=160 .............................
# [CV] . max_features=log2, n_estimators=160, score=0.743, total=   3.4s
# [CV] max_features=log2, n_estimators=160 .............................
# [CV] . max_features=log2, n_estimators=160, score=0.735, total=   2.3s
# [CV] max_features=log2, n_estimators=160 .............................
# [CV] . max_features=log2, n_estimators=160, score=0.724, total=   2.5s
# [CV] max_features=log2, n_estimators=160 .............................
# [CV] . max_features=log2, n_estimators=160, score=0.702, total=   2.1s
# [CV] max_features=log2, n_estimators=160 .............................
# [CV] . max_features=log2, n_estimators=160, score=0.735, total=   2.4s
# [CV] max_features=log2, n_estimators=170 .............................
# [CV] . max_features=log2, n_estimators=170, score=0.747, total=   2.3s
# [CV] max_features=log2, n_estimators=170 .............................
# [CV] . max_features=log2, n_estimators=170, score=0.730, total=   2.4s
# [CV] max_features=log2, n_estimators=170 .............................
# [CV] . max_features=log2, n_estimators=170, score=0.724, total=   2.4s
# [CV] max_features=log2, n_estimators=170 .............................
# [CV] . max_features=log2, n_estimators=170, score=0.707, total=   2.2s
# [CV] max_features=log2, n_estimators=170 .............................
# [CV] . max_features=log2, n_estimators=170, score=0.733, total=   2.4s
# [CV] max_features=log2, n_estimators=180 .............................
# [CV] . max_features=log2, n_estimators=180, score=0.745, total=   2.4s
# [CV] max_features=log2, n_estimators=180 .............................
# [CV] . max_features=log2, n_estimators=180, score=0.734, total=   2.6s
# [CV] max_features=log2, n_estimators=180 .............................
# [CV] . max_features=log2, n_estimators=180, score=0.726, total=   2.4s
# [CV] max_features=log2, n_estimators=180 .............................
# [CV] . max_features=log2, n_estimators=180, score=0.712, total=   2.6s
# [CV] max_features=log2, n_estimators=180 .............................
# [CV] . max_features=log2, n_estimators=180, score=0.730, total=   2.4s
# [CV] max_features=log2, n_estimators=190 .............................
# [CV] . max_features=log2, n_estimators=190, score=0.750, total=   2.7s
# [CV] max_features=log2, n_estimators=190 .............................
# [CV] . max_features=log2, n_estimators=190, score=0.734, total=   2.5s
# [CV] max_features=log2, n_estimators=190 .............................
# [CV] . max_features=log2, n_estimators=190, score=0.729, total=   2.8s
# [CV] max_features=log2, n_estimators=190 .............................
# [CV] . max_features=log2, n_estimators=190, score=0.715, total=   2.7s
# [CV] max_features=log2, n_estimators=190 .............................
# [CV] . max_features=log2, n_estimators=190, score=0.738, total=   2.6s
# [CV] max_features=log2, n_estimators=200 .............................
# [CV] . max_features=log2, n_estimators=200, score=0.747, total=   3.0s
# [CV] max_features=log2, n_estimators=200 .............................
# [CV] . max_features=log2, n_estimators=200, score=0.738, total=   2.6s
# [CV] max_features=log2, n_estimators=200 .............................
# [CV] . max_features=log2, n_estimators=200, score=0.723, total=   3.1s
# [CV] max_features=log2, n_estimators=200 .............................
# [CV] . max_features=log2, n_estimators=200, score=0.705, total=   2.6s
# [CV] max_features=log2, n_estimators=200 .............................
# [CV] . max_features=log2, n_estimators=200, score=0.744, total=   2.8s
# [CV] max_features=log2, n_estimators=210 .............................
# [CV] . max_features=log2, n_estimators=210, score=0.754, total=   2.9s
# [CV] max_features=log2, n_estimators=210 .............................
# [CV] . max_features=log2, n_estimators=210, score=0.735, total=   3.0s
# [CV] max_features=log2, n_estimators=210 .............................
# [CV] . max_features=log2, n_estimators=210, score=0.722, total=   3.1s
# [CV] max_features=log2, n_estimators=210 .............................
# [CV] . max_features=log2, n_estimators=210, score=0.716, total=   2.6s
# [CV] max_features=log2, n_estimators=210 .............................
# [CV] . max_features=log2, n_estimators=210, score=0.737, total=   3.5s
# [CV] max_features=log2, n_estimators=220 .............................
# [CV] . max_features=log2, n_estimators=220, score=0.746, total=   3.1s
# [CV] max_features=log2, n_estimators=220 .............................
# [CV] . max_features=log2, n_estimators=220, score=0.736, total=   3.0s
# [CV] max_features=log2, n_estimators=220 .............................
# [CV] . max_features=log2, n_estimators=220, score=0.727, total=   3.3s
# [CV] max_features=log2, n_estimators=220 .............................
# [CV] . max_features=log2, n_estimators=220, score=0.711, total=   2.9s
# [CV] max_features=log2, n_estimators=220 .............................
# [CV] . max_features=log2, n_estimators=220, score=0.734, total=   3.1s
# [CV] max_features=log2, n_estimators=230 .............................
# [CV] . max_features=log2, n_estimators=230, score=0.745, total=   3.3s
# [CV] max_features=log2, n_estimators=230 .............................
# [CV] . max_features=log2, n_estimators=230, score=0.740, total=   3.1s
# [CV] max_features=log2, n_estimators=230 .............................
# [CV] . max_features=log2, n_estimators=230, score=0.728, total=   3.4s
# [CV] max_features=log2, n_estimators=230 .............................
# [CV] . max_features=log2, n_estimators=230, score=0.713, total=   3.1s
# [CV] max_features=log2, n_estimators=230 .............................
# [CV] . max_features=log2, n_estimators=230, score=0.736, total=   3.1s
# [CV] max_features=log2, n_estimators=240 .............................
# [CV] . max_features=log2, n_estimators=240, score=0.755, total=   3.5s
# [CV] max_features=log2, n_estimators=240 .............................
# [CV] . max_features=log2, n_estimators=240, score=0.733, total=   3.3s
# [CV] max_features=log2, n_estimators=240 .............................
# [CV] . max_features=log2, n_estimators=240, score=0.727, total=   3.2s
# [CV] max_features=log2, n_estimators=240 .............................
# [CV] . max_features=log2, n_estimators=240, score=0.708, total=   3.5s
# [CV] max_features=log2, n_estimators=240 .............................
# [CV] . max_features=log2, n_estimators=240, score=0.739, total=   3.4s
# [CV] max_features=log2, n_estimators=250 .............................
# [CV] . max_features=log2, n_estimators=250, score=0.745, total=   3.4s
# [CV] max_features=log2, n_estimators=250 .............................
# [CV] . max_features=log2, n_estimators=250, score=0.737, total=   3.6s
# [CV] max_features=log2, n_estimators=250 .............................
# [CV] . max_features=log2, n_estimators=250, score=0.726, total=   3.7s
# [CV] max_features=log2, n_estimators=250 .............................
# [CV] . max_features=log2, n_estimators=250, score=0.716, total=   3.3s
# [CV] max_features=log2, n_estimators=250 .............................
# [CV] . max_features=log2, n_estimators=250, score=0.735, total=   3.5s
# [CV] max_features=log2, n_estimators=260 .............................
# [CV] . max_features=log2, n_estimators=260, score=0.745, total=   3.8s
# [CV] max_features=log2, n_estimators=260 .............................
# [CV] . max_features=log2, n_estimators=260, score=0.736, total=   3.5s
# [CV] max_features=log2, n_estimators=260 .............................
# [CV] . max_features=log2, n_estimators=260, score=0.725, total=   3.4s
# [CV] max_features=log2, n_estimators=260 .............................
# [CV] . max_features=log2, n_estimators=260, score=0.716, total=   3.7s
# [CV] max_features=log2, n_estimators=260 .............................
# [CV] . max_features=log2, n_estimators=260, score=0.737, total=   3.7s
# [CV] max_features=log2, n_estimators=270 .............................
# [CV] . max_features=log2, n_estimators=270, score=0.745, total=   3.5s
# [CV] max_features=log2, n_estimators=270 .............................
# [CV] . max_features=log2, n_estimators=270, score=0.744, total=   3.7s
# [CV] max_features=log2, n_estimators=270 .............................
# [CV] . max_features=log2, n_estimators=270, score=0.724, total=   3.9s
# [CV] max_features=log2, n_estimators=270 .............................
# [CV] . max_features=log2, n_estimators=270, score=0.711, total=   3.8s
# [CV] max_features=log2, n_estimators=270 .............................
# [CV] . max_features=log2, n_estimators=270, score=0.737, total=   3.5s
# [CV] max_features=log2, n_estimators=280 .............................
# [CV] . max_features=log2, n_estimators=280, score=0.747, total=   3.8s
# [CV] max_features=log2, n_estimators=280 .............................
# [CV] . max_features=log2, n_estimators=280, score=0.735, total=   4.1s
# [CV] max_features=log2, n_estimators=280 .............................
# [CV] . max_features=log2, n_estimators=280, score=0.721, total=   4.0s
# [CV] max_features=log2, n_estimators=280 .............................
# [CV] . max_features=log2, n_estimators=280, score=0.719, total=   3.8s
# [CV] max_features=log2, n_estimators=280 .............................
# [CV] . max_features=log2, n_estimators=280, score=0.736, total=   3.8s
# [CV] max_features=log2, n_estimators=290 .............................
# [CV] . max_features=log2, n_estimators=290, score=0.745, total=   3.9s
# [CV] max_features=log2, n_estimators=290 .............................
# [CV] . max_features=log2, n_estimators=290, score=0.731, total=   4.1s
# [CV] max_features=log2, n_estimators=290 .............................
# [CV] . max_features=log2, n_estimators=290, score=0.726, total=   4.1s
# [CV] max_features=log2, n_estimators=290 .............................
# [CV] . max_features=log2, n_estimators=290, score=0.717, total=   4.0s
# [CV] max_features=log2, n_estimators=290 .............................
# [CV] . max_features=log2, n_estimators=290, score=0.740, total=   4.0s
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed: 13.9min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=200, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': array([100, 110, 120, 130, 140, 150, 160, 170, 180, 190, 200, 210, 220,
#        230, 240, 250, 260, 270, 280, 290])},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'max_features': 'sqrt', 'n_estimators': 240}
# 0.7354539765243525

# %%
model_final = RandomForestClassifier(n_estimators=240, max_features='sqrt')
model_final.fit(X_train_scaled, y_train)

print(f'''
Training Score: {model_final.score(X_train_scaled, y_train)}
Testing Score: {model_final.score(X_test_scaled, y_test)}
''')
# Out:
# Training Score: 1.0
# Testing Score: 0.6933638443935927

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'random_forest_model_exoplanets.h5'
joblib.dump(model_final, filename)
# Out:
# ['random_forest_model_exoplanets.h5']
